# %%
import os
import json
import pandas as pd
import numpy as np

from tqdm.auto import tqdm

from llm_access import *

import pickle

from tqdm.auto import tqdm

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 500)

# %%
API_KEYS_FILE="/work/api_keys_20240427.json"

RESULTS="../../data/results_20240619_225219_simple_facts.pkl"

# %% [markdown]
# ## Prepare Groq access

# %%
groq_key = json.load(open(API_KEYS_FILE))['groq']

# %%
groq_interface = groq_access(groq_key, GROQ_LLAMA3_70B_MODEL)

# %% [markdown]
# ## Load the results

# %%
with open(RESULTS, "rb") as input_file:
    all_results = pickle.load(input_file)

# %%
all_results
# Out:
# [{'statement': 'Abhay Bhushan Pandey is an Indian computer scientist',
#   'model_answers': [{'statement': 'Abhay Bhushan Pandey is an Indian computer scientist',
#     'answers': [{'question': {'question': 'Who is Abhay Bhushan Pandey?',
#        'answer': 'an Indian computer scientist'},
#       'answers': ['Dr. Ashish Panda, an Indian computer scientist, invented a computer programming language called Python.',
#        'An Indian computer scientist who faced significant challenges due to his disability and overcame them to become',
#        'Abhay Bhushan Pandey is an Indian computer scientist who is known for his',
#        'An Indian computer scientist who invented a low-cost computer called the "ADOS',
#        'Abhay Bhushan Pandey was an Indian computer scientist who made significant contributions']},
#      {'question': {'question': "What is Abhay Bhushan Pandey's nationality?",
#        'answer': 'Indian'},
#       'answers': ['An Indian computer scientist.',
#        'He was an Indian computer scientist who became the first Indian to study at the Massachusetts Institute',
#        'An Indian computer scientist and polymath who became one of the most influential people in',
#        'An Indian computer scientist and educator who developed computer software to help teach programming to people with',
#        'He is an Indian computer scientist who invented computer software to help people with disabilities access computer']},
#      {'question': {'question': "What is Abhay Bhushan Pandey's profession?",
#        'answer': 'computer scientist'},
#       'answers': ['He was an Indian computer scientist who is credited with creating the first computer that was designed',
#        'A1: He is an Indian computer scientist who is best known for creating the Python programming language',
#        'He is an Indian computer scientist who developed the concept of computer programming from the need to provide an alternative',
#        'A. He is an Indian computer scientist who developed the concept of computer programming.',
#        'He was an Indian computer scientist who made significant contributions to the field of computer science.']}]}]},
#  {'statement': 'Abhay Bhushan Pandey made significant contributions to the development of the Internet TCP/IP architecture',
#   'model_answers': [{'statement': 'Abhay Bhushan Pandey is an Indian computer scientist',
#     'answers': [{'question': {'question': 'Who is Abhay Bhushan Pandey?',
#        'answer': 'an Indian computer scientist'},
#       'answers': ['Total: 15',
#        '- He was a key member of the Internet TCP/IP architecture in the Internet Middleware Project',
#        'He was a key member of the Internet Architecture team in the Indian Internet Project.',
#        'Abhay Bhushan Pandey',
#        'The original designator of the major new architecture for the Internet TCP/IP system,']},
#      {'question': {'question': "What is Abhay Bhushan Pandey's nationality?",
#        'answer': 'Indian'},
#       'answers': ['Indian',
#        'Indian',
#        'Person B: No, he is not a national.',
#        'Indian',
#        'Indian.']},
#      {'question': {'question': "What is Abhay Bhushan Pandey's profession?",
#        'answer': 'computer scientist'},
#       'answers': ['The official name of the five-member foreman-led team of internet TCP/',
#        'He was a key member of the Internet Silk Road team.',
#        '- He was a key member of the Internet Development Team in the 1998-2015 period.',
#        'Yes, Abhay Bhushan was a member of the Internet Team in the Internet Architecture',
#        'He was a key member of the Internet Central Function Team.']}]},
#    {'statement': 'Abhay Bhushan Pandey made significant contributions to the development of the Internet TCP/IP architecture',
#     'answers': [{'question': {'question': 'Who made significant contributions to the development of the Internet TCP/IP architecture?',
#        'answer': 'Abhay Bhushan Pandey'},
#       'answers': ['The Internet was originally developed by the United States Department of Defense, during',
#        'One significant contribution was the creation of the ARPANET, which laid the foundation',
#        'Tim Berners-Lee and Vint Cerf.',
#        'The development of the Internet TCP/IP architecture was made by many individuals, including Tim',
#        'Tim Berners-Lee and Ian Stewart.']},
#      {'question': {'question': 'What did Abhay Bhushan Pandey make significant contributions to?',
#        'answer': 'the development of the Internet TCP/IP architecture'},
#       'answers': ['Abhay Bhushan was a key member of the Internet Project Team in the',
#        'The development of the Internet TCP/IP architecture.',
#        'Abhay Bhushan was a key figure in the development of the Internet TCP',
#        'Abhay Bhushan was a key member of the Indian Internet Project team and',
#        'Abhay Bhushan made significant contributions to the development of the Internet Networking']}]}]}]

# %% [markdown]
# ## Compute the answers scores for all the results

# %%
statements_scores = {}

for i, edit_round in enumerate(all_results):

    print("******************************")
    print("Edit round {}".format(i))
    print("******************************")
    
    for statement in edit_round['model_answers']:

        print("\nStatement: {}".format(statement['statement']))
        
        if statement['statement'] not in statements_scores:
            statements_scores[statement['statement']] = []

        statement_round = {}
        statement_round['round'] = i
        statement_round['questions'] = []
        
        for question in statement['answers']:

            print("\n>> Question: {}".format(question['question']['question']))

            round_question = {}
            
            round_question['question'] = question['question']['question']

            question_scores = []
            question_evaluations = []

            for answer in question['answers']:
                score = answer_evaluation(groq_interface, 
                                          question['question'],
                                          answer)

                question_scores.append(int(score['score']))

                score['candidate_answer'] = answer
                
                question_evaluations.append(score)

            print(question_scores)
            
            round_question['mean_score'] = np.mean(question_scores)
            round_question['std_score'] = np.std(question_scores)
            round_question['evaluations'] = question_evaluations

            statement_round['questions'].append(round_question)

        statements_scores[statement['statement']].append(statement_round)
# Out:
# ******************************
# Edit round 0
# ******************************
#
# Statement: Abhay Bhushan Pandey is an Indian computer scientist
#
# >> Question: Who is Abhay Bhushan Pandey?
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "Who is Abhay Bhushan Pandey?"reference_answer: "an Indian computer scientist"
# candidate answer: "Dr. Ashish Panda, an Indian computer scientist, invented a computer programming language called Python."
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "Who is Abhay Bhushan Pandey?"reference_answer: "an Indian computer scientist"\ncandidate answer: "Dr. Ashish Panda, an Indian computer scientist, invented a computer programming language called Python."'}]
#
#
#
# {"reason": "The candidate answer refers to a different entity (Dr. Ashish Panda) from the reference question (Abhay Bhushan Pandey)", "score": "0"}
#
#
#
#
# {'reason': 'The candidate answer refers to a different entity (Dr. Ashish Panda) from the reference question (Abhay Bhushan Pandey)', 'score': '0', 'generated_text': '{"reason": "The candidate answer refers to a different entity (Dr. Ashish Panda) from the reference question (Abhay Bhushan Pandey)", "score": "0"}', 'prompt_tokens': 221, 'completion_tokens': 38, 'total_tokens': 259, 'total_time': 0.141221496}
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "Who is Abhay Bhushan Pandey?"reference_answer: "an Indian computer scientist"
# candidate answer: "An Indian computer scientist who faced significant challenges due to his disability and overcame them to become"
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "Who is Abhay Bhushan Pandey?"reference_answer: "an Indian computer scientist"\ncandidate answer: "An Indian computer scientist who faced significant challenges due to his disability and overcame them to become"'}]
#
#
#
# {"reason": "The candidate answer partially matches the reference answer and includes additional information not present in the reference question.", "score": "1"}
#
#
#
#
# {'reason': 'The candidate answer partially matches the reference answer and includes additional information not present in the reference question.', 'score': '1', 'generated_text': '{"reason": "The candidate answer partially matches the reference answer and includes additional information not present in the reference question.", "score": "1"}', 'prompt_tokens': 221, 'completion_tokens': 29, 'total_tokens': 250, 'total_time': 0.125549787}
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "Who is Abhay Bhushan Pandey?"reference_answer: "an Indian computer scientist"
# candidate answer: "Abhay Bhushan Pandey is an Indian computer scientist who is known for his"
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "Who is Abhay Bhushan Pandey?"reference_answer: "an Indian computer scientist"\ncandidate answer: "Abhay Bhushan Pandey is an Indian computer scientist who is known for his"'}]
#
#
#
# {"reason": "The candidate answer partially matches the reference answer and includes additional information not present in the reference question.", "score": "2"}
#
#
#
#
# {'reason': 'The candidate answer partially matches the reference answer and includes additional information not present in the reference question.', 'score': '2', 'generated_text': '{"reason": "The candidate answer partially matches the reference answer and includes additional information not present in the reference question.", "score": "2"}', 'prompt_tokens': 220, 'completion_tokens': 29, 'total_tokens': 249, 'total_time': 0.117225991}
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "Who is Abhay Bhushan Pandey?"reference_answer: "an Indian computer scientist"
# candidate answer: "An Indian computer scientist who invented a low-cost computer called the "ADOS"
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "Who is Abhay Bhushan Pandey?"reference_answer: "an Indian computer scientist"\ncandidate answer: "An Indian computer scientist who invented a low-cost computer called the "ADOS"'}]
#
#
#
# {"reason": "The candidate answer partially matches the reference answer and includes additional information not present in the reference question.", "score": "1"}
#
#
#
#
# {'reason': 'The candidate answer partially matches the reference answer and includes additional information not present in the reference question.', 'score': '1', 'generated_text': '{"reason": "The candidate answer partially matches the reference answer and includes additional information not present in the reference question.", "score": "1"}', 'prompt_tokens': 217, 'completion_tokens': 29, 'total_tokens': 246, 'total_time': 0.194575848}
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "Who is Abhay Bhushan Pandey?"reference_answer: "an Indian computer scientist"
# candidate answer: "Abhay Bhushan Pandey was an Indian computer scientist who made significant contributions"
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "Who is Abhay Bhushan Pandey?"reference_answer: "an Indian computer scientist"\ncandidate answer: "Abhay Bhushan Pandey was an Indian computer scientist who made significant contributions"'}]
#
#
#
# {"reason": "The candidate answer partially matches the reference answer and includes additional information not present in the reference question.", "score": "2"}
#
#
#
#
# {'reason': 'The candidate answer partially matches the reference answer and includes additional information not present in the reference question.', 'score': '2', 'generated_text': '{"reason": "The candidate answer partially matches the reference answer and includes additional information not present in the reference question.", "score": "2"}', 'prompt_tokens': 219, 'completion_tokens': 29, 'total_tokens': 248, 'total_time': 0.12045219699999998}
# [0, 1, 2, 1, 2]
#
# >> Question: What is Abhay Bhushan Pandey's nationality?
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "What is Abhay Bhushan Pandey's nationality?"reference_answer: "Indian"
# candidate answer: "An Indian computer scientist."
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "What is Abhay Bhushan Pandey\'s nationality?"reference_answer: "Indian"\ncandidate answer: "An Indian computer scientist."'}]
#
#
#
# {"reason": "The candidate answer partially matches the reference answer and includes extra information not present in the reference question.", "score": "1"}
#
#
#
#
# {'reason': 'The candidate answer partially matches the reference answer and includes extra information not present in the reference question.', 'score': '1', 'generated_text': '{"reason": "The candidate answer partially matches the reference answer and includes extra information not present in the reference question.", "score": "1"}', 'prompt_tokens': 206, 'completion_tokens': 29, 'total_tokens': 235, 'total_time': 0.115952993}
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "What is Abhay Bhushan Pandey's nationality?"reference_answer: "Indian"
# candidate answer: "He was an Indian computer scientist who became the first Indian to study at the Massachusetts Institute"
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "What is Abhay Bhushan Pandey\'s nationality?"reference_answer: "Indian"\ncandidate answer: "He was an Indian computer scientist who became the first Indian to study at the Massachusetts Institute"'}]
#
#
#
# {"reason": "The candidate answer partially matches the reference answer and includes extra information not present in the reference question.", "score": "1"}
#
#
#
#
# {'reason': 'The candidate answer partially matches the reference answer and includes extra information not present in the reference question.', 'score': '1', 'generated_text': '{"reason": "The candidate answer partially matches the reference answer and includes extra information not present in the reference question.", "score": "1"}', 'prompt_tokens': 219, 'completion_tokens': 29, 'total_tokens': 248, 'total_time': 0.159427708}
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "What is Abhay Bhushan Pandey's nationality?"reference_answer: "Indian"
# candidate answer: "An Indian computer scientist and polymath who became one of the most influential people in"
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "What is Abhay Bhushan Pandey\'s nationality?"reference_answer: "Indian"\ncandidate answer: "An Indian computer scientist and polymath who became one of the most influential people in"'}]
#
#
#
# {"reason": "The candidate answer only partially matches the reference answer information and includes information not present in the reference question.", "score": "1"}
#
#
#
#
# {'reason': 'The candidate answer only partially matches the reference answer information and includes information not present in the reference question.', 'score': '1', 'generated_text': '{"reason": "The candidate answer only partially matches the reference answer information and includes information not present in the reference question.", "score": "1"}', 'prompt_tokens': 218, 'completion_tokens': 30, 'total_tokens': 248, 'total_time': 0.11974374000000002}
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "What is Abhay Bhushan Pandey's nationality?"reference_answer: "Indian"
# candidate answer: "An Indian computer scientist and educator who developed computer software to help teach programming to people with"
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "What is Abhay Bhushan Pandey\'s nationality?"reference_answer: "Indian"\ncandidate answer: "An Indian computer scientist and educator who developed computer software to help teach programming to people with"'}]
#
#
#
# {"reason": "The candidate answer only partially matches the reference answer information and includes extra information not present in the reference question.", "score": "1"}
#
#
#
#
# {'reason': 'The candidate answer only partially matches the reference answer information and includes extra information not present in the reference question.', 'score': '1', 'generated_text': '{"reason": "The candidate answer only partially matches the reference answer information and includes extra information not present in the reference question.", "score": "1"}', 'prompt_tokens': 219, 'completion_tokens': 31, 'total_tokens': 250, 'total_time': 0.12374523700000001}
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "What is Abhay Bhushan Pandey's nationality?"reference_answer: "Indian"
# candidate answer: "He is an Indian computer scientist who invented computer software to help people with disabilities access computer"
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "What is Abhay Bhushan Pandey\'s nationality?"reference_answer: "Indian"\ncandidate answer: "He is an Indian computer scientist who invented computer software to help people with disabilities access computer"'}]
#
#
#
# {"reason": "The candidate answer partially matches the reference answer and includes additional information not present in the reference question.", "score": "1"}
#
#
#
#
# {'reason': 'The candidate answer partially matches the reference answer and includes additional information not present in the reference question.', 'score': '1', 'generated_text': '{"reason": "The candidate answer partially matches the reference answer and includes additional information not present in the reference question.", "score": "1"}', 'prompt_tokens': 219, 'completion_tokens': 29, 'total_tokens': 248, 'total_time': 0.11990999799999999}
# [1, 1, 1, 1, 1]
#
# >> Question: What is Abhay Bhushan Pandey's profession?
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "What is Abhay Bhushan Pandey's profession?"reference_answer: "computer scientist"
# candidate answer: "He was an Indian computer scientist who is credited with creating the first computer that was designed"
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "What is Abhay Bhushan Pandey\'s profession?"reference_answer: "computer scientist"\ncandidate answer: "He was an Indian computer scientist who is credited with creating the first computer that was designed"'}]
#
#
#
# {"reason": "The candidate answer partially matches the reference answer and includes additional information not present in the reference question.", "score": "2"}
#
#
#
#
# {'reason': 'The candidate answer partially matches the reference answer and includes additional information not present in the reference question.', 'score': '2', 'generated_text': '{"reason": "The candidate answer partially matches the reference answer and includes additional information not present in the reference question.", "score": "2"}', 'prompt_tokens': 220, 'completion_tokens': 29, 'total_tokens': 249, 'total_time': 0.12132392}
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "What is Abhay Bhushan Pandey's profession?"reference_answer: "computer scientist"
# candidate answer: "A1: He is an Indian computer scientist who is best known for creating the Python programming language"
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "What is Abhay Bhushan Pandey\'s profession?"reference_answer: "computer scientist"\ncandidate answer: "A1: He is an Indian computer scientist who is best known for creating the Python programming language"'}]
#
#
#
# {"reason": "The candidate answer partially matches the reference answer and includes extra information not present in the reference question.", "score": "2"}
#
#
#
#
# {'reason': 'The candidate answer partially matches the reference answer and includes extra information not present in the reference question.', 'score': '2', 'generated_text': '{"reason": "The candidate answer partially matches the reference answer and includes extra information not present in the reference question.", "score": "2"}', 'prompt_tokens': 222, 'completion_tokens': 29, 'total_tokens': 251, 'total_time': 0.119618719}
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "What is Abhay Bhushan Pandey's profession?"reference_answer: "computer scientist"
# candidate answer: "He is an Indian computer scientist who developed the concept of computer programming from the need to provide an alternative"
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "What is Abhay Bhushan Pandey\'s profession?"reference_answer: "computer scientist"\ncandidate answer: "He is an Indian computer scientist who developed the concept of computer programming from the need to provide an alternative"'}]
#
#
#
# {"reason": "The candidate answer partially matches the reference answer and includes extra information not present in the reference question.", "score": "1"}
#
#
#
#
# {'reason': 'The candidate answer partially matches the reference answer and includes extra information not present in the reference question.', 'score': '1', 'generated_text': '{"reason": "The candidate answer partially matches the reference answer and includes extra information not present in the reference question.", "score": "1"}', 'prompt_tokens': 223, 'completion_tokens': 29, 'total_tokens': 252, 'total_time': 0.12724602699999998}
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "What is Abhay Bhushan Pandey's profession?"reference_answer: "computer scientist"
# candidate answer: "A. He is an Indian computer scientist who developed the concept of computer programming."
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "What is Abhay Bhushan Pandey\'s profession?"reference_answer: "computer scientist"\ncandidate answer: "A. He is an Indian computer scientist who developed the concept of computer programming."'}]
#
#
#
# {"reason": "The candidate answer partially matches the reference answer and includes extra information not present in the reference question.", "score": "1"}
#
#
#
#
# {'reason': 'The candidate answer partially matches the reference answer and includes extra information not present in the reference question.', 'score': '1', 'generated_text': '{"reason": "The candidate answer partially matches the reference answer and includes extra information not present in the reference question.", "score": "1"}', 'prompt_tokens': 218, 'completion_tokens': 29, 'total_tokens': 247, 'total_time': 0.123032213}
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "What is Abhay Bhushan Pandey's profession?"reference_answer: "computer scientist"
# candidate answer: "He was an Indian computer scientist who made significant contributions to the field of computer science."
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "What is Abhay Bhushan Pandey\'s profession?"reference_answer: "computer scientist"\ncandidate answer: "He was an Indian computer scientist who made significant contributions to the field of computer science."'}]
#
#
#
# {"reason": "The candidate answer provides more information than the reference answer, but it is still relevant and accurate.", "score": "2"}
#
#
#
#
# {'reason': 'The candidate answer provides more information than the reference answer, but it is still relevant and accurate.', 'score': '2', 'generated_text': '{"reason": "The candidate answer provides more information than the reference answer, but it is still relevant and accurate.", "score": "2"}', 'prompt_tokens': 219, 'completion_tokens': 29, 'total_tokens': 248, 'total_time': 0.116799051}
# [2, 2, 1, 1, 2]
# ******************************
# Edit round 1
# ******************************
#
# Statement: Abhay Bhushan Pandey is an Indian computer scientist
#
# >> Question: Who is Abhay Bhushan Pandey?
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "Who is Abhay Bhushan Pandey?"reference_answer: "an Indian computer scientist"
# candidate answer: "Total: 15"
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "Who is Abhay Bhushan Pandey?"reference_answer: "an Indian computer scientist"\ncandidate answer: "Total: 15"'}]
#
#
#
# {"reason": "The candidate answer refers to a different entity from the reference question", "score": "0"}
#
#
#
#
# {'reason': 'The candidate answer refers to a different entity from the reference question', 'score': '0', 'generated_text': '{"reason": "The candidate answer refers to a different entity from the reference question", "score": "0"}', 'prompt_tokens': 207, 'completion_tokens': 23, 'total_tokens': 230, 'total_time': 0.106355526}
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "Who is Abhay Bhushan Pandey?"reference_answer: "an Indian computer scientist"
# candidate answer: "- He was a key member of the Internet TCP/IP architecture in the Internet Middleware Project"
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "Who is Abhay Bhushan Pandey?"reference_answer: "an Indian computer scientist"\ncandidate answer: "- He was a key member of the Internet TCP/IP architecture in the Internet Middleware Project"'}]
#
#
#
# {"reason": "The candidate answer does not directly answer the question, it provides additional information about Abhay Bhushan Pandey, but does not state what he is.", "score": "2"}
#
#
#
#
# {'reason': 'The candidate answer does not directly answer the question, it provides additional information about Abhay Bhushan Pandey, but does not state what he is.', 'score': '2', 'generated_text': '{"reason": "The candidate answer does not directly answer the question, it provides additional information about Abhay Bhushan Pandey, but does not state what he is.", "score": "2"}', 'prompt_tokens': 219, 'completion_tokens': 41, 'total_tokens': 260, 'total_time': 0.15347806}
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "Who is Abhay Bhushan Pandey?"reference_answer: "an Indian computer scientist"
# candidate answer: "He was a key member of the Internet Architecture team in the Indian Internet Project."
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "Who is Abhay Bhushan Pandey?"reference_answer: "an Indian computer scientist"\ncandidate answer: "He was a key member of the Internet Architecture team in the Indian Internet Project."'}]
#
#
#
# {"reason": "The candidate answer only partially matches the reference answer information and includes information not present in the reference question.", "score": "1"}
#
#
#
#
# {'reason': 'The candidate answer only partially matches the reference answer information and includes information not present in the reference question.', 'score': '1', 'generated_text': '{"reason": "The candidate answer only partially matches the reference answer information and includes information not present in the reference question.", "score": "1"}', 'prompt_tokens': 218, 'completion_tokens': 30, 'total_tokens': 248, 'total_time': 0.120477537}
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "Who is Abhay Bhushan Pandey?"reference_answer: "an Indian computer scientist"
# candidate answer: "Abhay Bhushan Pandey"
# ...
#
#
#
# {"reason": "The candidate answer only partially matches the reference answer information and includes information not present in the reference question.", "score": "1"}
#
#
#
#
# {'reason': 'The candidate answer only partially matches the reference answer information and includes information not present in the reference question.', 'score': '1', 'generated_text': '{"reason": "The candidate answer only partially matches the reference answer information and includes information not present in the reference question.", "score": "1"}', 'prompt_tokens': 226, 'completion_tokens': 30, 'total_tokens': 256, 'total_time': 0.125297563}
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "Who made significant contributions to the development of the Internet TCP/IP architecture?"reference_answer: "Abhay Bhushan Pandey"
# candidate answer: "Tim Berners-Lee and Ian Stewart."
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "Who made significant contributions to the development of the Internet TCP/IP architecture?"reference_answer: "Abhay Bhushan Pandey"\ncandidate answer: "Tim Berners-Lee and Ian Stewart."'}]
#
#
#
# {"reason": "The candidate answer refers to a different entity from the reference question.", "score": "0"}
#
#
#
#
# {'reason': 'The candidate answer refers to a different entity from the reference question.', 'score': '0', 'generated_text': '{"reason": "The candidate answer refers to a different entity from the reference question.", "score": "0"}', 'prompt_tokens': 218, 'completion_tokens': 23, 'total_tokens': 241, 'total_time': 0.130620258}
# [1, 1, 0, 1, 0]
#
# >> Question: What did Abhay Bhushan Pandey make significant contributions to?
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "What did Abhay Bhushan Pandey make significant contributions to?"reference_answer: "the development of the Internet TCP/IP architecture"
# candidate answer: "Abhay Bhushan was a key member of the Internet Project Team in the"
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "What did Abhay Bhushan Pandey make significant contributions to?"reference_answer: "the development of the Internet TCP/IP architecture"\ncandidate answer: "Abhay Bhushan was a key member of the Internet Project Team in the"'}]
#
#
#
# {"reason": "The candidate answer only partially matches the reference answer information and ends in an incomplete sentence.", "score": "1"}
#
#
#
#
# {'reason': 'The candidate answer only partially matches the reference answer information and ends in an incomplete sentence.', 'score': '1', 'generated_text': '{"reason": "The candidate answer only partially matches the reference answer information and ends in an incomplete sentence.", "score": "1"}', 'prompt_tokens': 227, 'completion_tokens': 27, 'total_tokens': 254, 'total_time': 0.148236043}
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "What did Abhay Bhushan Pandey make significant contributions to?"reference_answer: "the development of the Internet TCP/IP architecture"
# candidate answer: "The development of the Internet TCP/IP architecture."
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "What did Abhay Bhushan Pandey make significant contributions to?"reference_answer: "the development of the Internet TCP/IP architecture"\ncandidate answer: "The development of the Internet TCP/IP architecture."'}]
#
#
#
# {"reason":"The candidate answer is a perfect match with the reference answer.", "score":"3"}
#
#
#
#
# {'reason': 'The candidate answer is a perfect match with the reference answer.', 'score': '3', 'generated_text': '{"reason":"The candidate answer is a perfect match with the reference answer.", "score":"3"}', 'prompt_tokens': 219, 'completion_tokens': 20, 'total_tokens': 239, 'total_time': 0.098069147}
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "What did Abhay Bhushan Pandey make significant contributions to?"reference_answer: "the development of the Internet TCP/IP architecture"
# candidate answer: "Abhay Bhushan was a key figure in the development of the Internet TCP"
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "What did Abhay Bhushan Pandey make significant contributions to?"reference_answer: "the development of the Internet TCP/IP architecture"\ncandidate answer: "Abhay Bhushan was a key figure in the development of the Internet TCP"'}]
#
#
#
# {"reason": "The candidate answer partially matches the reference answer information.", "score": "2"}
#
#
#
#
# {'reason': 'The candidate answer partially matches the reference answer information.', 'score': '2', 'generated_text': '{"reason": "The candidate answer partially matches the reference answer information.", "score": "2"}', 'prompt_tokens': 227, 'completion_tokens': 20, 'total_tokens': 247, 'total_time': 0.094010607}
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "What did Abhay Bhushan Pandey make significant contributions to?"reference_answer: "the development of the Internet TCP/IP architecture"
# candidate answer: "Abhay Bhushan was a key member of the Indian Internet Project team and"
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "What did Abhay Bhushan Pandey make significant contributions to?"reference_answer: "the development of the Internet TCP/IP architecture"\ncandidate answer: "Abhay Bhushan was a key member of the Indian Internet Project team and"'}]
#
#
#
# {"reason": "The candidate answer only partially matches the reference answer information and ends in an incomplete sentence.", "score": "1"}
#
#
#
#
# {'reason': 'The candidate answer only partially matches the reference answer information and ends in an incomplete sentence.', 'score': '1', 'generated_text': '{"reason": "The candidate answer only partially matches the reference answer information and ends in an incomplete sentence.", "score": "1"}', 'prompt_tokens': 227, 'completion_tokens': 27, 'total_tokens': 254, 'total_time': 0.120369201}
#
# Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:
# 1. Start with score 3;
# 2. If the candidate answer only partially matches the reference answer information, decrement 1 point;
# 3. If the candidate answer includes information not present in the reference question, decrement 1 point;
# 4. If the candidate answer end in an incomplete sentence, decrement 1 point;
# 5. If the candidate answer refers to a different entity from reference question, attribute score 0.
#
# Provide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.
#
# reference_question: "What did Abhay Bhushan Pandey make significant contributions to?"reference_answer: "the development of the Internet TCP/IP architecture"
# candidate answer: "Abhay Bhushan made significant contributions to the development of the Internet Networking"
# [{'role': 'system', 'content': 'You evaluate a list of answers, taking a (question, answer) pair as reference.'}, {'role': 'user', 'content': 'Provide a score for the list of candidate answers, considering a pair of (reference_question, reference_answer), according to the following procedure:\n1. Start with score 3;\n2. If the candidate answer only partially matches the reference answer information, decrement 1 point;\n3. If the candidate answer includes information not present in the reference question, decrement 1 point;\n4. If the candidate answer end in an incomplete sentence, decrement 1 point;\n5. If the candidate answer refers to a different entity from reference question, attribute score 0.\n\nProvide your answer only in JSON, nothing else: {"reason":"<your-reasoning-for-the-score>", "score":"<answer-score>"}.\n\nreference_question: "What did Abhay Bhushan Pandey make significant contributions to?"reference_answer: "the development of the Internet TCP/IP architecture"\ncandidate answer: "Abhay Bhushan made significant contributions to the development of the Internet Networking"'}]
#
#
#
# {"reason": "The candidate answer partially matches the reference answer information and includes some extra information not present in the reference question.", "score": "1"}
#
#
#
#
# {'reason': 'The candidate answer partially matches the reference answer information and includes some extra information not present in the reference question.', 'score': '1', 'generated_text': '{"reason": "The candidate answer partially matches the reference answer information and includes some extra information not present in the reference question.", "score": "1"}', 'prompt_tokens': 226, 'completion_tokens': 31, 'total_tokens': 257, 'total_time': 0.162830816}
# [1, 3, 2, 1, 1]

# %% [markdown]
# ## Create a table with the results

# %%
results_table = []

for statement, rounds in statements_scores.items():

    print(statement)
    
    for evaluation in rounds:
        for question in evaluation['questions']:
            results = {}
            results['statement'] = statement
            results['round'] = evaluation['round']
            results['question'] = question['question']
            results['mean_score'] = question['mean_score']
            results['std_score'] = question['std_score']
    
            results_table.append(results)

results_table_df = pd.DataFrame(results_table)
# Out:
# Abhay Bhushan Pandey is an Indian computer scientist
# Abhay Bhushan Pandey made significant contributions to the development of the Internet TCP/IP architecture

# %%
results_table_df
# Out:
#                                                                                                     statement  \
# 0                                                        Abhay Bhushan Pandey is an Indian computer scientist
# 1                                                        Abhay Bhushan Pandey is an Indian computer scientist
# 2                                                        Abhay Bhushan Pandey is an Indian computer scientist
# 3                                                        Abhay Bhushan Pandey is an Indian computer scientist
# 4                                                        Abhay Bhushan Pandey is an Indian computer scientist
# 5                                                        Abhay Bhushan Pandey is an Indian computer scientist
# 6  Abhay Bhushan Pandey made significant contributions to the development of the Internet TCP/IP architecture
# 7  Abhay Bhushan Pandey made significant contributions to the development of the Internet TCP/IP architecture
#
#    round  \
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
# 5      1
# 6      1
# 7      1
#
#                                                                                      question  \
# 0                                                                Who is Abhay Bhushan Pandey?
# 1                                                 What is Abhay Bhushan Pandey's nationality?
# 2                                                  What is Abhay Bhushan Pandey's profession?
# 3                                                                Who is Abhay Bhushan Pandey?
# 4                                                 What is Abhay Bhushan Pandey's nationality?
# 5                                                  What is Abhay Bhushan Pandey's profession?
# 6  Who made significant contributions to the development of the Internet TCP/IP architecture?
# 7                            What did Abhay Bhushan Pandey make significant contributions to?
#
#    mean_score  std_score
# 0         1.2   0.748331
# 1         1.0   0.000000
# 2         1.6   0.489898
# 3         1.0   0.894427
# 4         2.4   1.200000
# 5         0.6   0.489898
# 6         0.6   0.489898
# 7         1.6   0.800000

# %%
output_filename = "evaluations_{}".format(os.path.basename(RESULTS))

# %%
with open(os.path.join(os.path.dirname(RESULTS), output_filename), "wb") as output_file:
    pickle.dump({"statements_scores": statements_scores,
                 "results_table_df": results_table_df}, output_file, pickle.HIGHEST_PROTOCOL)
