# %%
import os
import json
import pandas as pd
import numpy as np

from tqdm.auto import tqdm

from llm_access import *

import pickle

from tqdm.auto import tqdm

# %%
# %load_ext autoreload
# %autoreload 2

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 500)

# %%
BIOGRAPHY_DATASET="../../llm_multiagent_debate/biography/article.json"
API_KEYS_FILE="/work/api_keys_20240427.json"

# %% [markdown]
# ## Read Biography dataset, which will be the factual associations base

# %%
biography = json.load(open(BIOGRAPHY_DATASET))

# %%
people = list(biography.keys())

# %%
people
# Out:
# ['Aaron Sloman',
#  'Abhay Bhushan',
#  'Adam Dunkels',
#  'Adele Goldberg (computer scientist)',
#  'Adi Shamir',
#  'Adriaan van Wijngaarden',
#  'Alan Dix',
#  'Alan Edelman',
#  'Alan Kay',
#  'Alan Mycroft',
#  'Alan Perlis',
#  'Alberto Ciaramella',
#  'Alexander Dewdney',
#  'Alexander Stepanov',
#  'Alfred Aho',
#  'Alston Householder',
#  'Amir Pnueli',
#  'Anders P. Ravn',
#  'Andrew Barto',
#  'Andrew Chi-Chih Yao',
#  'Andrew Donald Booth',
#  'Andrew Herbert',
#  'Andrew Koenig (programmer)',
#  'Andrew McCallum',
#  'Andrew Ng',
#  'Andrew S. Tanenbaum',
#  'Andrew V. Goldberg',
#  'Andrew Viterbi',
#  'Andrey Nikolaevich Kolmogorov',
#  'Andries van Dam',
#  'Anil K. Jain (computer scientist, born 1948)',
#  'Anita Borg',
#  'Annie Easley',
#  'Aravind K. Joshi',
#  'Arne Sølvberg',
#  'Arvind (computer scientist)',
#  'Ashok Goel',
#  'Atta ur Rehman Khan',
#  'Austin Tate',
#  'Avie Tevanian',
#  'Avinash Kak',
#  'Azriel Rosenfeld',
#  'Barbara Engelhardt',
#  'Barbara Liskov',
#  'Barry Boehm',
#  'Beatrice Helen Worsley',
#  'Ben Shneiderman',
#  'Bernard Richards',
#  'Bernard de Neumann',
#  'Bernhard Schölkopf',
#  'Bernhard Thalheim',
#  'Bert Bos',
#  'Bertrand Meyer',
#  'Betty Holberton',
#  'Bigtable',
#  'Bill Gropp',
#  'Bill Joy',
#  'Bjarne Stroustrup',
#  'Bonnie Nardi',
#  'Brian Cantwell Smith',
#  'Brian Kernighan',
#  'Bruce Arden',
#  'Bruce Schneier',
#  'Bryan Cantrill',
#  'Butler Lampson',
#  'Börje Langefors',
#  'C. A. R. Hoare',
#  'C. J. van Rijsbergen',
#  'Carl Hewitt',
#  'Carl Sassenrath',
#  'Carol Spradling',
#  'Carroll Morgan (computer scientist)',
#  'Cecilia Berdichevsky',
#  'Charles Bachman',
#  'Charles E. Leiserson',
#  'Charles Geschke',
#  'Charles H. Lindsey',
#  'Charles H. Moore',
#  'Charles P. Thacker',
#  'Charles Stark Draper',
#  'Charlotte Froese Fischer',
#  'Chris Lattner',
#  'Chris McKinstry',
#  'Christopher J. Date',
#  'Christopher Riche Evans',
#  'Christopher Strachey',
#  'Christos Papadimitriou',
#  'Cicely Popplewell',
#  'Claude Sammut',
#  'Cleve Moler',
#  'Cliff Jones (computer scientist)',
#  'Cliff Shaw',
#  'Colette Rolland',
#  'Cornelis H. A. Koster',
#  'Corrado Böhm',
#  'D. R. Fulkerson',
#  'DJ Patil',
#  'Dan Ingalls',
#  'Dan Jurafsky',
#  'Dana Scott',
#  'Danese Cooper',
#  'Daniel J. Bernstein',
#  'Daniel P. Friedman',
#  'Daniel Siewiorek',
#  'Daniel Sleator',
#  'Daniel Thalmann',
#  'Darrell Long',
#  'David A. Bader',
#  'David A. Wagner',
#  'David Blei',
#  'David C. Evans',
#  'David Canfield Smith',
#  'David F. Bacon',
#  'David Gelernter',
#  'David H. D. Warren',
#  'David J. Brown (computer scientist)',
#  'David Korn (computer scientist)',
#  'David Liddle',
#  'David P. Anderson',
#  'David P. Reed',
#  'David Park (computer scientist)',
#  'David Parnas',
#  'David Patterson (computer scientist)',
#  'David S. Johnson',
#  'David Turner (computer scientist)',
#  'David Waltz',
#  'David Wheeler (computer scientist)',
#  'Dennis E. Wisnosky',
#  'Dennis Ritchie',
#  'Derek McAuley',
#  'Donald Firesmith',
#  'Donald Knuth',
#  'Dora Metcalf',
#  'Dorothy Blum',
#  'Dorothy E. Denning',
#  'Dorothy Vaughan',
#  'Douglas Comer',
#  'Douglas Lenat',
#  'Douglas McIlroy',
#  'Douglas T. Ross',
#  'Dragomir R. Radev',
#  'E. Allen Emerson',
#  'Edgar F. Codd',
#  'Edmund M. Clarke',
#  'Edward D. Lazowska',
#  'Edward Feigenbaum',
#  'Edward Felten',
#  'Edward H. Shortliffe',
#  'Edward Yourdon',
#  'Edwin Catmull',
#  'Edwin E. Tozer',
#  'Eiiti Wada',
#  'Eldon C. Hall',
#  'Emil Post',
#  'Eric Hehner',
#  'Erik Demaine',
#  'Eugene Luks',
#  'Fernando J. Corbató',
#  'Frances E. Allen',
#  'Franco Preparata',
#  'Frank Harary',
#  'François Vernadat',
#  'Fred B. Schneider',
#  'Frieder Nake',
#  'Friedrich L. Bauer',
#  'G.M. Nijssen',
#  'Gary William Flake',
#  'Gastón Gonnet',
#  'Gene Amdahl',
#  'Gene Golub',
#  'Geoffrey Hinton',
#  'George Novacky',
#  'George Sadowsky',
#  'Gerald Jay Sussman',
#  'Gerard Holzmann',
#  'Gerard Salton',
#  'Gernot Heiser',
#  'Gerrit Blaauw',
#  'Gillian Lovegrove',
#  'Gio Wiederhold',
#  'Glen Culler',
#  'Gloria Townsend',
#  'Godfried Toussaint',
#  'Gordon Bell',
#  'Gordon Cormack',
#  'Gordon Moore',
#  'Greg Nelson (computer scientist)',
#  'Gregor Kiczales',
#  'Gregory Chaitin',
#  'Grzegorz Rozenberg',
#  'Guido van Rossum',
#  'Guy L. Steele, Jr.',
#  'Gábor Tardos',
#  'Hans Moravec',
#  'Hans Zantema',
#  'Hardik Gohel',
#  'Harry Bouwman',
#  'Haskell Curry',
#  'Hector Garcia-Molina',
#  'Herbert W. Franke',
#  'Herman Hollerith',
#  'Hugo de Garis',
#  'Hussein Zedan',
#  'Ian Coldwater',
#  'Ian Goldberg',
#  'Ian Goodfellow',
#  'Igor Hawryszkiewycz',
#  'Ivan Sutherland',
#  'Ivar Jacobson',
#  'J.C.R. Licklider',
#  'J Strother Moore',
#  'Jack Dongarra',
#  'Jack E. Bresenham',
#  'Jack Minker',
#  'Jacques Cohen (computer scientist)',
#  'Jaime Teevan',
#  'James Cooley',
#  'James G. Mitchell',
#  'James G. Nell',
#  'James Gosling',
#  'James H. Wilkinson',
#  'James Hendler',
#  'James Rumbaugh',
#  'James Z. Wang',
#  'Jan Dietz',
#  'Jan Weglarz',
#  'Janet L. Kolodner',
#  'Jean E. Sammet',
#  'Jean Ichbiah',
#  'Jeff Bonwick',
#  'Jeff Rulifson',
#  'Jeffrey D. Ullman',
#  'Jeffrey Scott Vitter',
#  'Jeremy Gibbons',
#  'Jerre Noe',
#  'Jiawei Han',
#  'Jie Wu',
#  'Jill Zimmerman',
#  'Jim Gray (computer scientist)',
#  'Jochen Liedtke',
#  'John Cocke (computer scientist)',
#  'John George Kemeny',
#  'John Henry Holland',
#  'John Hopcroft',
#  'John Horton Conway',
#  'John Hughes (computer scientist)',
#  'John Koza',
#  'John Krogstie',
#  'John L. Hennessy',
#  'John Lions',
#  'John Mashey',
#  'John Mauchly',
#  'John McCarthy (computer scientist)',
#  "John O'Sullivan (engineer)",
#  'John Ousterhout',
#  'John P. Moon',
#  'John Presper Eckert',
#  'John Vincent Atanasoff',
#  'John Yen',
#  'Jon Crowcroft',
#  'Jon Michael Dunn',
#  'Jonathan Bowen',
#  'Jonathan James',
#  'Joseph F Traub',
#  'Joseph Halpern',
#  'Joseph Henry Wegstein',
#  'Joseph Kruskal',
#  'Joseph Sifakis',
#  'Joshua Lederberg',
#  'Joyce K. Reynolds',
#  'Juan E. Gilbert',
#  'Juan Pavón',
#  'Judy Goldsmith (computer scientist)',
#  'Juris Hartmanis',
#  'Jürg Gutknecht',
#  'Jürgen Schmidhuber',
#  'Karlheinz Brandenburg',
#  'Kathleen Booth',
#  'Kathy Pham',
#  'Kelsey Hightower',
#  'Ken Forbus',
#  'Ken Kennedy (computer scientist)',
#  'Ken Thompson (computer programmer)',
#  'Kit Cosper',
#  'Klara Dan von Neumann',
#  'Klaus-Robert Müller',
#  'Kleene closure',
#  'Kristen Nygaard',
#  'Kunihiko Fukushima',
#  'Kurt Bollacker',
#  'L. R. Ford, Jr.',
#  'Larry Tesler',
#  'Latanya Sweeney',
#  'Lawrence J. Fogel',
#  'Lawrence M. Breed',
#  'Lawrence Paulson',
#  'Lee Giles',
#  'Lenore Blum',
#  'Leonard Adleman',
#  'Leonard Kleinrock',
#  'Leonid Levin',
#  'Leslie Lamport',
#  'Leslie Valiant',
#  'Linus Torvalds',
#  'Lisa Anthony',
#  'Lisa Gelobter',
#  'Lotfi Zadeh',
#  'Luca Cardelli',
#  'M. A. Rothman',
#  'Maciej Stachowiak',
#  'Madhu Sudan',
#  'Mahadev Satyanarayanan',
#  'Mahmoud Samir Fayed',
#  'Manfred K. Warmuth',
#  'Manindra Agrawal',
#  'Manny M Lehman',
#  'Manolis Kellis',
#  'Manuela M. Veloso',
#  'Marco Dorigo',
#  'Marek Karpinski',
#  'Margaret Burnett',
#  'Margaret Hamilton (scientist)',
#  'Mario Szegedy',
#  'Mario Tchou',
#  'Mark Overmars',
#  'Mark Weiser',
#  'Marshall Kirk McKusick',
#  'Martin Campbell-Kelly',
#  'Martin Charles Golumbic',
#  'Martin Fowler (software engineer)',
#  'Martin Hellman',
#  'Martin Richards (computer scientist)',
#  'Marvin Minsky',
#  'Mary Allen Wilkes',
#  'Mary Jane Irwin',
#  'Mathai Joseph',
#  'Matthew Dillon (computer scientist)',
#  'Maurice Nivat',
#  'Maurice Vincent Wilkes',
#  'Michael Dertouzos',
#  'Michael Guy',
#  'Michael Kölling',
#  'Michael L. Scott',
#  'Michael O. Rabin',
#  'Michael Stonebraker',
#  'Mihai Nadin',
#  'Mihalis Yannakakis',
#  'Mike Woodger',
#  'Monica S. Lam',
#  'Murray Turoff',
#  'Nadia Magnenat Thalmann',
#  'Nancy Lynch',
#  'Neeraj Kayal',
#  'Neil Daswani',
#  'Neil J. Gunther',
#  'Nello Cristianini',
#  'Nico Habermann',
#  'Nigel Shadbolt',
#  'Niklaus Wirth',
#  'Nils John Nilsson',
#  'Nobuo Yoneda',
#  'Oded Goldreich',
#  'Olaf Storaasli (computing)',
#  'Ole-Johan Dahl',
#  'Oleg A. Mukhanov',
#  'Oren Etzioni',
#  'Parisa Tabriz',
#  'Paritosh Pandya',
#  'Patrick Cousot',
#  'Paul Dourish',
#  'Paul Graham (computer programmer)',
#  'Paul Hudak',
#  'Paul Justin Compton',
#  'Paul Vitanyi',
#  'Paul Vixie',
#  'Peter Eades',
#  'Peter J. Denning',
#  'Peter J. Weinberger',
#  'Peter Landin',
#  'Peter Norvig',
#  "Peter O'Hearn",
#  'Peter Wegner',
#  'Philip Don Estridge',
#  'Philip Emeagwali',
#  'Philip Wadler',
#  'Philip Woodward',
#  'Phiwa Nkambule',
#  'Pino Caballero Gil',
#  'Poul-Henning Kamp',
#  'Ralph Griswold',
#  'Ramanathan V. Guha',
#  'Ramesh Jain',
#  'Ramesh Sitaraman',
#  'Randy Pausch',
#  'Rapelang Rabana',
#  'Rasmus Lerdorf',
#  'Rediet Abebe',
#  'Reinder van de Riet',
#  'Richard Hamming',
#  'Richard J. Lipton',
#  'Richard Karp',
#  'Richard Veryard',
#  'Richard W. Conway',
#  'Robert C. Martin',
#  'Robert Cailliau',
#  'Robert Dewar',
#  'Robert France',
#  'Robert Griesemer',
#  'Robert Kowalski',
#  'Robert L. Glass',
#  'Robert M. Graham (computer scientist)',
#  'Robert S. Boyer',
#  'Robert Sedgewick (computer scientist)',
#  'Robert Sproull',
#  'Robert Tappan Morris',
#  'Robert W. Floyd',
#  'Roberto Ierusalimschy',
#  'Roberto Pieraccini',
#  'Robin Milner',
#  'Rod Canion',
#  'Roger Moore (computer scientist)',
#  'Rohini Kesavan Srihari',
#  'Roland Carl Backhouse',
#  'Ron Rivest',
#  'Ronald Stamper',
#  'Rosemary Candlin',
#  'Rudolf Bayer',
#  'Rudy Rucker',
#  'Rózsa Péter',
#  'Sally Floyd',
#  'Salvatore Stolfo',
#  'Samir Das',
#  'Samson Abramsky',
#  'Sanjay Ghemawat',
#  'Sanjeev Arora',
#  'Sankar Pal',
#  'Sargur Srihari',
#  'Sarita Schoenebeck',
#  'Schahram Dustdar',
#  'Scott Fahlman',
#  'Scott Shenker',
#  'Sebastian Thrun',
#  'Serge Abiteboul',
#  'Sergiy Vilkomir',
#  'Severo Ornstein',
#  'Seymour Ginsburg',
#  'Shafi Goldwasser',
#  'Shakuntala Atre',
#  'Shang-Hua Teng',
#  'Shashi Shekhar (scientist)',
#  'Sheila Greibach',
#  'Shimon Even',
#  'Shlomo Zilberstein',
#  'Shmuel Winograd',
#  'Silvio Micali',
#  'Simon Peyton Jones',
#  'Sjaak Brinkkemper',
#  'Sophie Wilson',
#  'Stanley Zdonik',
#  'Stephen C. Johnson',
#  'Stephen Cole Kleene',
#  'Stephen Cook',
#  'Stephen Muggleton',
#  'Stephen R. Bourne',
#  'Stephen Wolfram',
#  'Steve Lawrence (computer scientist)',
#  'Steve Omohundro',
#  'Steve Schneider (computer scientist)',
#  'Steve Ward (computer scientist)',
#  'Steve Whittaker',
#  'Steven M. Bellovin',
#  'Steven Rudich',
#  'Steven Spewak',
#  'Sue Black (computer scientist)',
#  'Susan L. Graham',
#  'Susan Owicki',
#  'T. William Olle',
#  'Ted Kaehler',
#  'Terry Winograd',
#  'Thomas E. Kurtz',
#  'Thomas Sterling (computing)',
#  'Tim Finin',
#  'Tin Kam Ho',
#  'Tom Gruber',
#  'Tom M. Mitchell',
#  'Tom Maibaum',
#  'Tracy Camp',
#  'Tracy Chou',
#  'Trygve Reenskaug',
#  'Ujjwal Maulik',
#  'Umar Saif',
#  'Umesh Vazirani',
#  'Valerie Taylor (computer scientist)',
#  'Victor Bahl',
#  'Vinod Dham',
#  'Vint Cerf',
#  'Vladimir Vapnik',
#  'Volker Strassen',
#  'W. Bruce Croft',
#  'W. Richard Stevens',
#  'Walter F. Tichy',
#  'Walter Savitch',
#  'Watts Humphrey',
#  'Wendy Hall',
#  'Wil van der Aalst',
#  'Wilhelm Schickard',
#  'Willem van der Poel',
#  'William H. Press',
#  'William Kahan',
#  'William Wulf',
#  'Wim Ebbinkhuijsen',
#  'Winifred Asprey',
#  'Winston W. Royce',
#  'Xiaoming Fu',
#  'Yale Patt',
#  'Yanhong Annie Liu',
#  'Yann LeCun',
#  'Yoav Freund',
#  'Yorick Wilks',
#  'Yuri Matiyasevich',
#  'Zohar Manna',
#  'Zoubin Ghahramani',
#  'Zvi Galil',
#  'Éva Tardos']

# %%
person_to_consider = people[1]

# %%
person_to_consider
# Out:
# 'Abhay Bhushan'

# %%
print(biography[person_to_consider])
# Out:
# - Abhay Bhushan Pandey is an Indian computer scientist.
# - He made significant contributions to the development of the Internet TCP/IP architecture.
# - He is the author of the File Transfer Protocol and early versions of email protocols.
# - He graduated from the first batch of Indian Institute of Technology Kanpur in 1965 with a B.Tech in electrical engineering.
# - He received a Masters in electrical engineering and a degree in Management from the MIT Sloan School of Management.
# - He worked on developing FTP and email protocols for ARPANet and subsequent Internet.
# - He was a Director at the Institute of Engineering and Rural Technology in Allahabad and a senior manager in Engineering and Development of Xerox.
# - He was a co-founder of YieldUP International and Portola Communications.
# - He is currently chairman of Asquare Inc., Secretary of Indians for Collective Action and former President of the IIT-Kanpur Foundation.

# %% [markdown]
# ## Prepare Groq access

# %%
groq_key = json.load(open(API_KEYS_FILE))['groq']

# %%
groq_interface = groq_access(groq_key, GROQ_LLAMA3_70B_MODEL)

# %% [markdown]
# ## Extract factual associations from a biography

# %%
facts = factual_association_3_step_extraction(groq_interface, biography[person_to_consider])
# Out:
# Read the text and return a list of all factual associations you can extract only from the text information. Write independent and complete sentences; repeat the main subject to avoid pronouns.
#
# Only output the JSON format, nothing else: {"comments": "<any-comment>", "sentences": ["<sentence-1>", ..., "<sentence-n>"]}
#
# Text: "
#
# - Abhay Bhushan Pandey is an Indian computer scientist.
# - He made significant contributions to the development of the Internet TCP/IP architecture.
# - He is the author of the File Transfer Protocol and early versions of email protocols.
# - He graduated from the first batch of Indian Institute of Technology Kanpur in 1965 with a B.Tech in electrical engineering.
# - He received a Masters in electrical engineering and a degree in Management from the MIT Sloan School of Management.
# - He worked on developing FTP and email protocols for ARPANet and subsequent Internet.
# - He was a Director at the Institute of Engineering and Rural Technology in Allahabad and a senior manager in Engineering and Development of Xerox.
# - He was a co-founder of YieldUP International and Portola Communications.
# - He is currently chairman of Asquare Inc., Secretary of Indians for Collective Action and former President of the IIT-Kanpur Foundation."
# [{'role': 'system', 'content': 'You read a text and break it down in a sequence of factual associations sentences.'}, {'role': 'user', 'content': 'Read the text and return a list of all factual associations you can extract only from the text information. Write independent and complete sentences; repeat the main subject to avoid pronouns.\n\nOnly output the JSON format, nothing else: {"comments": "<any-comment>", "sentences": ["<sentence-1>", ..., "<sentence-n>"]}\n\nText: "\n\n- Abhay Bhushan Pandey is an Indian computer scientist.\n- He made significant contributions to the development of the Internet TCP/IP architecture.\n- He is the author of the File Transfer Protocol and early versions of email protocols.\n- He graduated from the first batch of Indian Institute of Technology Kanpur in 1965 with a B.Tech in electrical engineering.\n- He received a Masters in electrical engineering and a degree in Management from the MIT Sloan School of Management.\n- He worked on developing FTP and email protocols for ARPANet and subsequent Internet.\n- He was a Director at the Institute of Engineering and Rural Technology in Allahabad and a senior manager in Engineering and Development of Xerox.\n- He was a co-founder of YieldUP International and Portola Communications.\n- He is currently chairman of Asquare Inc., Secretary of Indians for Collective Action and former President of the IIT-Kanpur Foundation."'}]
#
#
# ---------------------
# {"comments": "", "sentences": ["Abhay Bhushan Pandey is an Indian computer scientist.", "Abhay Bhushan Pandey made significant contributions to the development of the Internet TCP/IP architecture.", "Abhay Bhushan Pandey is the author of the File Transfer Protocol and early versions of email protocols.", "Abhay Bhushan Pandey graduated from the Indian Institute of Technology Kanpur in 1965 with a B.Tech in electrical engineering.", "Abhay Bhushan Pandey received a Masters in electrical engineering and a degree in Management from the MIT Sloan School of Management.", "Abhay Bhushan Pandey worked on developing FTP and email protocols for ARPANet and subsequent Internet.", "Abhay Bhushan Pandey was a Director at the Institute of Engineering and Rural Technology in Allahabad.", "Abhay Bhushan Pandey was a senior manager in Engineering and Development of Xerox.", "Abhay Bhushan Pandey was a co-founder of YieldUP International.", "Abhay Bhushan Pandey was a co-founder of Portola Communications.", "Abhay Bhushan Pandey is currently chairman of Asquare Inc.", "Abhay Bhushan Pandey is Secretary of Indians for Collective Action.", "Abhay Bhushan Pandey is a former President of the IIT-Kanpur Foundation."]}
# ---------------------
#
#
#
#
# ---------------------
# {"comments": "", "sentences": ["Abhay Bhushan Pandey is an Indian computer scientist.", "Abhay Bhushan Pandey made significant contributions to the development of the Internet TCP/IP architecture.", "Abhay Bhushan Pandey is the author of the File Transfer Protocol and early versions of email protocols.", "Abhay Bhushan Pandey graduated from the Indian Institute of Technology Kanpur in 1965 with a B.Tech in electrical engineering.", "Abhay Bhushan Pandey received a Masters in electrical engineering and a degree in Management from the MIT Sloan School of Management.", "Abhay Bhushan Pandey worked on developing FTP and email protocols for ARPANet and subsequent Internet.", "Abhay Bhushan Pandey was a Director at the Institute of Engineering and Rural Technology in Allahabad.", "Abhay Bhushan Pandey was a senior manager in Engineering and Development of Xerox.", "Abhay Bhushan Pandey was a co-founder of YieldUP International.", "Abhay Bhushan Pandey was a co-founder of Portola Communications.", "Abhay Bhushan Pandey is currently chairman of Asquare Inc.", "Abhay Bhushan Pandey is Secretary of Indians for Collective Action.", "Abhay Bhushan Pandey is a former President of the IIT-Kanpur Foundation."]}
# ---------------------
#
#
#
# {'comments': '', 'sentences': ['Abhay Bhushan Pandey is an Indian computer scientist.', 'Abhay Bhushan Pandey made significant contributions to the development of the Internet TCP/IP architecture.', 'Abhay Bhushan Pandey is the author of the File Transfer Protocol and early versions of email protocols.', 'Abhay Bhushan Pandey graduated from the Indian Institute of Technology Kanpur in 1965 with a B.Tech in electrical engineering.', 'Abhay Bhushan Pandey received a Masters in electrical engineering and a degree in Management from the MIT Sloan School of Management.', 'Abhay Bhushan Pandey worked on developing FTP and email protocols for ARPANet and subsequent Internet.', 'Abhay Bhushan Pandey was a Director at the Institute of Engineering and Rural Technology in Allahabad.', 'Abhay Bhushan Pandey was a senior manager in Engineering and Development of Xerox.', 'Abhay Bhushan Pandey was a co-founder of YieldUP International.', 'Abhay Bhushan Pandey was a co-founder of Portola Communications.', 'Abhay Bhushan Pandey is currently chairman of Asquare Inc.', 'Abhay Bhushan Pandey is Secretary of Indians for Collective Action.', 'Abhay Bhushan Pandey is a former President of the IIT-Kanpur Foundation.'], 'generated_text': '{"comments": "", "sentences": ["Abhay Bhushan Pandey is an Indian computer scientist.", "Abhay Bhushan Pandey made significant contributions to the development of the Internet TCP/IP architecture.", "Abhay Bhushan Pandey is the author of the File Transfer Protocol and early versions of email protocols.", "Abhay Bhushan Pandey graduated from the Indian Institute of Technology Kanpur in 1965 with a B.Tech in electrical engineering.", "Abhay Bhushan Pandey received a Masters in electrical engineering and a degree in Management from the MIT Sloan School of Management.", "Abhay Bhushan Pandey worked on developing FTP and email protocols for ARPANet and subsequent Internet.", "Abhay Bhushan Pandey was a Director at the Institute of Engineering and Rural Technology in Allahabad.", "Abhay Bhushan Pandey was a senior manager in Engineering and Development of Xerox.", "Abhay Bhushan Pandey was a co-founder of YieldUP International.", "Abhay Bhushan Pandey was a co-founder of Portola Communications.", "Abhay Bhushan Pandey is currently chairman of Asquare Inc.", "Abhay Bhushan Pandey is Secretary of Indians for Collective Action.", "Abhay Bhushan Pandey is a former President of the IIT-Kanpur Foundation."]}', 'prompt_tokens': 284, 'completion_tokens': 278, 'total_tokens': 562, 'total_time': 0.842327797}
#
# Break each sentence in "subject", "relation" and "object":
# 1. Identify the "subject" of the relation;
# 2. Identify the minimal "object" of the relation, including up to the last 3 words of the original sentence;
# 3. Include in the "relation" every word between the "subject" and "object".
# 4. Don't create a "relation" with only verb.
#
# Only output the JSON format, nothing else before or after: {"sentences":[{"subject":"<subject-1>", "relation":"<relation-1>", "object":"<object-1>"}, ..., {"subject":"<subject-n>", "relation":"<relation-n>", "object":"<object-n>"}]}
#
# Sentences:
# "Abhay Bhushan Pandey is an Indian computer scientist."
# "Abhay Bhushan Pandey made significant contributions to the development of the Internet TCP/IP architecture."
# "Abhay Bhushan Pandey is the author of the File Transfer Protocol and early versions of email protocols."
# "Abhay Bhushan Pandey graduated from the Indian Institute of Technology Kanpur in 1965 with a B.Tech in electrical engineering."
# "Abhay Bhushan Pandey received a Masters in electrical engineering and a degree in Management from the MIT Sloan School of Management."
# "Abhay Bhushan Pandey worked on developing FTP and email protocols for ARPANet and subsequent Internet."
# "Abhay Bhushan Pandey was a Director at the Institute of Engineering and Rural Technology in Allahabad."
# "Abhay Bhushan Pandey was a senior manager in Engineering and Development of Xerox."
# "Abhay Bhushan Pandey was a co-founder of YieldUP International."
# "Abhay Bhushan Pandey was a co-founder of Portola Communications."
# "Abhay Bhushan Pandey is currently chairman of Asquare Inc."
# "Abhay Bhushan Pandey is Secretary of Indians for Collective Action."
# "Abhay Bhushan Pandey is a former President of the IIT-Kanpur Foundation."
#
#
#
# ---------------------
# {"sentences":[{"subject":"Abhay Bhushan Pandey", "relation":"is", "object":"an Indian computer scientist"},{"subject":"Abhay Bhushan Pandey", "relation":"made significant contributions to the development of the", "object":"Internet TCP/IP architecture"},{"subject":"Abhay Bhushan Pandey", "relation":"is the author of the", "object":"File Transfer Protocol and early versions of email protocols"},{"subject":"Abhay Bhushan Pandey", "relation":"graduated from the", "object":"Indian Institute of Technology Kanpur in 1965 with a B.Tech in electrical engineering"},{"subject":"Abhay Bhushan Pandey", "relation":"received a Masters in electrical engineering and a degree in Management from the", "object":"MIT Sloan School of Management"},{"subject":"Abhay Bhushan Pandey", "relation":"worked on developing FTP and email protocols for", "object":"ARPANet and subsequent Internet"},{"subject":"Abhay Bhushan Pandey", "relation":"was a Director at the", "object":"Institute of Engineering and Rural Technology in Allahabad"},{"subject":"Abhay Bhushan Pandey", "relation":"was a senior manager in Engineering and Development of", "object":"Xerox"},{"subject":"Abhay Bhushan Pandey", "relation":"was a co-founder of", "object":"YieldUP International"},{"subject":"Abhay Bhushan Pandey", "relation":"was a co-founder of", "object":"Portola Communications"},{"subject":"Abhay Bhushan Pandey", "relation":"is currently chairman of", "object":"Asquare Inc"},{"subject":"Abhay Bhushan Pandey", "relation":"is", "object":"Secretary of Indians for Collective Action"},{"subject":"Abhay Bhushan Pandey", "relation":"is a former President of the", "object":"IIT-Kanpur Foundation"}]}
# ---------------------
#
#
#
#
# ---------------------
# {"sentences":[{"subject":"Abhay Bhushan Pandey", "relation":"is", "object":"an Indian computer scientist"},{"subject":"Abhay Bhushan Pandey", "relation":"made significant contributions to the development of the", "object":"Internet TCP/IP architecture"},{"subject":"Abhay Bhushan Pandey", "relation":"is the author of the", "object":"File Transfer Protocol and early versions of email protocols"},{"subject":"Abhay Bhushan Pandey", "relation":"graduated from the", "object":"Indian Institute of Technology Kanpur in 1965 with a B.Tech in electrical engineering"},{"subject":"Abhay Bhushan Pandey", "relation":"received a Masters in electrical engineering and a degree in Management from the", "object":"MIT Sloan School of Management"},{"subject":"Abhay Bhushan Pandey", "relation":"worked on developing FTP and email protocols for", "object":"ARPANet and subsequent Internet"},{"subject":"Abhay Bhushan Pandey", "relation":"was a Director at the", "object":"Institute of Engineering and Rural Technology in Allahabad"},{"subject":"Abhay Bhushan Pandey", "relation":"was a senior manager in Engineering and Development of", "object":"Xerox"},{"subject":"Abhay Bhushan Pandey", "relation":"was a co-founder of", "object":"YieldUP International"},{"subject":"Abhay Bhushan Pandey", "relation":"was a co-founder of", "object":"Portola Communications"},{"subject":"Abhay Bhushan Pandey", "relation":"is currently chairman of", "object":"Asquare Inc"},{"subject":"Abhay Bhushan Pandey", "relation":"is", "object":"Secretary of Indians for Collective Action"},{"subject":"Abhay Bhushan Pandey", "relation":"is a former President of the", "object":"IIT-Kanpur Foundation"}]}
# ---------------------
#
#
#
# {'sentences': [{'subject': 'Abhay Bhushan Pandey', 'relation': 'is', 'object': 'an Indian computer scientist'}, {'subject': 'Abhay Bhushan Pandey', 'relation': 'made significant contributions to the development of the', 'object': 'Internet TCP/IP architecture'}, {'subject': 'Abhay Bhushan Pandey', 'relation': 'is the author of the', 'object': 'File Transfer Protocol and early versions of email protocols'}, {'subject': 'Abhay Bhushan Pandey', 'relation': 'graduated from the', 'object': 'Indian Institute of Technology Kanpur in 1965 with a B.Tech in electrical engineering'}, {'subject': 'Abhay Bhushan Pandey', 'relation': 'received a Masters in electrical engineering and a degree in Management from the', 'object': 'MIT Sloan School of Management'}, {'subject': 'Abhay Bhushan Pandey', 'relation': 'worked on developing FTP and email protocols for', 'object': 'ARPANet and subsequent Internet'}, {'subject': 'Abhay Bhushan Pandey', 'relation': 'was a Director at the', 'object': 'Institute of Engineering and Rural Technology in Allahabad'}, {'subject': 'Abhay Bhushan Pandey', 'relation': 'was a senior manager in Engineering and Development of', 'object': 'Xerox'}, {'subject': 'Abhay Bhushan Pandey', 'relation': 'was a co-founder of', 'object': 'YieldUP International'}, {'subject': 'Abhay Bhushan Pandey', 'relation': 'was a co-founder of', 'object': 'Portola Communications'}, {'subject': 'Abhay Bhushan Pandey', 'relation': 'is currently chairman of', 'object': 'Asquare Inc'}, {'subject': 'Abhay Bhushan Pandey', 'relation': 'is', 'object': 'Secretary of Indians for Collective Action'}, {'subject': 'Abhay Bhushan Pandey', 'relation': 'is a former President of the', 'object': 'IIT-Kanpur Foundation'}], 'generated_text': '{"sentences":[{"subject":"Abhay Bhushan Pandey", "relation":"is", "object":"an Indian computer scientist"},{"subject":"Abhay Bhushan Pandey", "relation":"made significant contributions to the development of the", "object":"Internet TCP/IP architecture"},{"subject":"Abhay Bhushan Pandey", "relation":"is the author of the", "object":"File Transfer Protocol and early versions of email protocols"},{"subject":"Abhay Bhushan Pandey", "relation":"graduated from the", "object":"Indian Institute of Technology Kanpur in 1965 with a B.Tech in electrical engineering"},{"subject":"Abhay Bhushan Pandey", "relation":"received a Masters in electrical engineering and a degree in Management from the", "object":"MIT Sloan School of Management"},{"subject":"Abhay Bhushan Pandey", "relation":"worked on developing FTP and email protocols for", "object":"ARPANet and subsequent Internet"},{"subject":"Abhay Bhushan Pandey", "relation":"was a Director at the", "object":"Institute of Engineering and Rural Technology in Allahabad"},{"subject":"Abhay Bhushan Pandey", "relation":"was a senior manager in Engineering and Development of", "object":"Xerox"},{"subject":"Abhay Bhushan Pandey", "relation":"was a co-founder of", "object":"YieldUP International"},{"subject":"Abhay Bhushan Pandey", "relation":"was a co-founder of", "object":"Portola Communications"},{"subject":"Abhay Bhushan Pandey", "relation":"is currently chairman of", "object":"Asquare Inc"},{"subject":"Abhay Bhushan Pandey", "relation":"is", "object":"Secretary of Indians for Collective Action"},{"subject":"Abhay Bhushan Pandey", "relation":"is a former President of the", "object":"IIT-Kanpur Foundation"}]}', 'prompt_tokens': 428, 'completion_tokens': 394, 'total_tokens': 822, 'total_time': 1.189557811}
# Repeated relation: "was a co-founder of"
# {'subject': 'Abhay Bhushan Pandey', 'relation': 'was a co-founder of', 'object': 'Portola Communications'}
#
#
# ---------------------
# {"sentence": {"subject":"Abhay Bhushan Pandey", "relation":"co-founded", "object":"Portola Communications"}}
# ---------------------
#
#
#
#
# ---------------------
# {"sentence": {"subject":"Abhay Bhushan Pandey", "relation":"co-founded", "object":"Portola Communications"}}
# ---------------------
#
#
# Repeated relation: "is"
# {'subject': 'Abhay Bhushan Pandey', 'relation': 'is', 'object': 'Secretary of Indians for Collective Action'}
#
#
# ---------------------
# {"sentence": {"subject":"Abhay Bhushan Pandey", "relation":"serves as", "object":"Secretary of Indians for Collective Action"}}
# ---------------------
#
#
#
#
# ---------------------
# {"sentence": {"subject":"Abhay Bhushan Pandey", "relation":"serves as", "object":"Secretary of Indians for Collective Action"}}
# ---------------------

# %%
facts['sentences']
# Out:
# [{'subject': 'Abhay Bhushan Pandey',
#   'relation': 'is',
#   'object': 'an Indian computer scientist'},
#  {'subject': 'Abhay Bhushan Pandey',
#   'relation': 'made significant contributions to the development of the',
#   'object': 'Internet TCP/IP architecture'},
#  {'subject': 'Abhay Bhushan Pandey',
#   'relation': 'is the author of the',
#   'object': 'File Transfer Protocol and early versions of email protocols'},
#  {'subject': 'Abhay Bhushan Pandey',
#   'relation': 'graduated from the',
#   'object': 'Indian Institute of Technology Kanpur in 1965 with a B.Tech in electrical engineering'},
#  {'subject': 'Abhay Bhushan Pandey',
#   'relation': 'received a Masters in electrical engineering and a degree in Management from the',
#   'object': 'MIT Sloan School of Management'},
#  {'subject': 'Abhay Bhushan Pandey',
#   'relation': 'worked on developing FTP and email protocols for',
#   'object': 'ARPANet and subsequent Internet'},
#  {'subject': 'Abhay Bhushan Pandey',
#   'relation': 'was a Director at the',
#   'object': 'Institute of Engineering and Rural Technology in Allahabad'},
#  {'subject': 'Abhay Bhushan Pandey',
#   'relation': 'was a senior manager in Engineering and Development of',
#   'object': 'Xerox'},
#  {'subject': 'Abhay Bhushan Pandey',
#   'relation': 'was a co-founder of',
#   'object': 'YieldUP International'},
#  {'subject': 'Abhay Bhushan Pandey',
#   'relation': 'co-founded',
#   'object': 'Portola Communications'},
#  {'subject': 'Abhay Bhushan Pandey',
#   'relation': 'is currently chairman of',
#   'object': 'Asquare Inc'},
#  {'subject': 'Abhay Bhushan Pandey',
#   'relation': 'serves as',
#   'object': 'Secretary of Indians for Collective Action'},
#  {'subject': 'Abhay Bhushan Pandey',
#   'relation': 'is a former President of the',
#   'object': 'IIT-Kanpur Foundation'}]

# %%
len(facts['sentences'])
# Out:
# 13

# %% [markdown]
# ## Generate questions from the same biography

# %%
text_questions = questions_generation(groq_interface, biography[person_to_consider])
# Out:
# Read the text and generate questions following the steps:
# 1. Extract a list of factual associations from the text, including implicit information and temporal relations.
# 2. Create a list of questions and answers from the factual associations.
# Only output the JSON format, nothing else: {"questions":[{"question": "<question-1>", "answer": "<answer-1>"}, ..., {"question": "<question-n>", "answer": "<answer-n>"}].
#
# Text: "
#
# - Abhay Bhushan Pandey is an Indian computer scientist.
# - He made significant contributions to the development of the Internet TCP/IP architecture.
# - He is the author of the File Transfer Protocol and early versions of email protocols.
# - He graduated from the first batch of Indian Institute of Technology Kanpur in 1965 with a B.Tech in electrical engineering.
# - He received a Masters in electrical engineering and a degree in Management from the MIT Sloan School of Management.
# - He worked on developing FTP and email protocols for ARPANet and subsequent Internet.
# - He was a Director at the Institute of Engineering and Rural Technology in Allahabad and a senior manager in Engineering and Development of Xerox.
# - He was a co-founder of YieldUP International and Portola Communications.
# - He is currently chairman of Asquare Inc., Secretary of Indians for Collective Action and former President of the IIT-Kanpur Foundation."
# [{'role': 'system', 'content': 'You read a text, break it down in a sequence of factual associations sentences and generate questions about them.'}, {'role': 'user', 'content': 'Read the text and generate questions following the steps:\n1. Extract a list of factual associations from the text, including implicit information and temporal relations.\n2. Create a list of questions and answers from the factual associations.\nOnly output the JSON format, nothing else: {"questions":[{"question": "<question-1>", "answer": "<answer-1>"}, ..., {"question": "<question-n>", "answer": "<answer-n>"}].\n\nText: "\n\n- Abhay Bhushan Pandey is an Indian computer scientist.\n- He made significant contributions to the development of the Internet TCP/IP architecture.\n- He is the author of the File Transfer Protocol and early versions of email protocols.\n- He graduated from the first batch of Indian Institute of Technology Kanpur in 1965 with a B.Tech in electrical engineering.\n- He received a Masters in electrical engineering and a degree in Management from the MIT Sloan School of Management.\n- He worked on developing FTP and email protocols for ARPANet and subsequent Internet.\n- He was a Director at the Institute of Engineering and Rural Technology in Allahabad and a senior manager in Engineering and Development of Xerox.\n- He was a co-founder of YieldUP International and Portola Communications.\n- He is currently chairman of Asquare Inc., Secretary of Indians for Collective Action and former President of the IIT-Kanpur Foundation."'}]
#
#
# ---------------------
# {"questions":[{"question": "What is Abhay Bhushan Pandey's profession?", "answer": "Indian computer scientist."}, {"question": "What did Abhay Bhushan Pandey contribute to?", "answer": "development of the Internet TCP/IP architecture."}, {"question": "What protocols did Abhay Bhushan Pandey author?", "answer": "File Transfer Protocol and early versions of email protocols."}, {"question": "Where did Abhay Bhushan Pandey graduate from in 1965?", "answer": "Indian Institute of Technology Kanpur."}, {"question": "What degree did Abhay Bhushan Pandey receive from the MIT Sloan School of Management?", "answer": "Masters in electrical engineering and a degree in Management."}, {"question": "What networks did Abhay Bhushan Pandey work on developing FTP and email protocols for?", "answer": "ARPANet and subsequent Internet."}, {"question": "What positions did Abhay Bhushan Pandey hold at the Institute of Engineering and Rural Technology and Xerox?", "answer": "Director and senior manager in Engineering and Development."}, {"question": "What companies did Abhay Bhushan Pandey co-found?", "answer": "YieldUP International and Portola Communications."}, {"question": "What positions does Abhay Bhushan Pandey currently hold?", "answer": "chairman of Asquare Inc., Secretary of Indians for Collective Action and former President of the IIT-Kanpur Foundation."}]}
# ---------------------
#
#
#
#
# ---------------------
# {"questions":[{"question": "What is Abhay Bhushan Pandey's profession?", "answer": "Indian computer scientist."}, {"question": "What did Abhay Bhushan Pandey contribute to?", "answer": "development of the Internet TCP/IP architecture."}, {"question": "What protocols did Abhay Bhushan Pandey author?", "answer": "File Transfer Protocol and early versions of email protocols."}, {"question": "Where did Abhay Bhushan Pandey graduate from in 1965?", "answer": "Indian Institute of Technology Kanpur."}, {"question": "What degree did Abhay Bhushan Pandey receive from the MIT Sloan School of Management?", "answer": "Masters in electrical engineering and a degree in Management."}, {"question": "What networks did Abhay Bhushan Pandey work on developing FTP and email protocols for?", "answer": "ARPANet and subsequent Internet."}, {"question": "What positions did Abhay Bhushan Pandey hold at the Institute of Engineering and Rural Technology and Xerox?", "answer": "Director and senior manager in Engineering and Development."}, {"question": "What companies did Abhay Bhushan Pandey co-found?", "answer": "YieldUP International and Portola Communications."}, {"question": "What positions does Abhay Bhushan Pandey currently hold?", "answer": "chairman of Asquare Inc., Secretary of Indians for Collective Action and former President of the IIT-Kanpur Foundation."}]}
# ---------------------
#
#
#
# {'questions': [{'question': "What is Abhay Bhushan Pandey's profession?", 'answer': 'Indian computer scientist.'}, {'question': 'What did Abhay Bhushan Pandey contribute to?', 'answer': 'development of the Internet TCP/IP architecture.'}, {'question': 'What protocols did Abhay Bhushan Pandey author?', 'answer': 'File Transfer Protocol and early versions of email protocols.'}, {'question': 'Where did Abhay Bhushan Pandey graduate from in 1965?', 'answer': 'Indian Institute of Technology Kanpur.'}, {'question': 'What degree did Abhay Bhushan Pandey receive from the MIT Sloan School of Management?', 'answer': 'Masters in electrical engineering and a degree in Management.'}, {'question': 'What networks did Abhay Bhushan Pandey work on developing FTP and email protocols for?', 'answer': 'ARPANet and subsequent Internet.'}, {'question': 'What positions did Abhay Bhushan Pandey hold at the Institute of Engineering and Rural Technology and Xerox?', 'answer': 'Director and senior manager in Engineering and Development.'}, {'question': 'What companies did Abhay Bhushan Pandey co-found?', 'answer': 'YieldUP International and Portola Communications.'}, {'question': 'What positions does Abhay Bhushan Pandey currently hold?', 'answer': 'chairman of Asquare Inc., Secretary of Indians for Collective Action and former President of the IIT-Kanpur Foundation.'}], 'generated_text': '{"questions":[{"question": "What is Abhay Bhushan Pandey\'s profession?", "answer": "Indian computer scientist."}, {"question": "What did Abhay Bhushan Pandey contribute to?", "answer": "development of the Internet TCP/IP architecture."}, {"question": "What protocols did Abhay Bhushan Pandey author?", "answer": "File Transfer Protocol and early versions of email protocols."}, {"question": "Where did Abhay Bhushan Pandey graduate from in 1965?", "answer": "Indian Institute of Technology Kanpur."}, {"question": "What degree did Abhay Bhushan Pandey receive from the MIT Sloan School of Management?", "answer": "Masters in electrical engineering and a degree in Management."}, {"question": "What networks did Abhay Bhushan Pandey work on developing FTP and email protocols for?", "answer": "ARPANet and subsequent Internet."}, {"question": "What positions did Abhay Bhushan Pandey hold at the Institute of Engineering and Rural Technology and Xerox?", "answer": "Director and senior manager in Engineering and Development."}, {"question": "What companies did Abhay Bhushan Pandey co-found?", "answer": "YieldUP International and Portola Communications."}, {"question": "What positions does Abhay Bhushan Pandey currently hold?", "answer": "chairman of Asquare Inc., Secretary of Indians for Collective Action and former President of the IIT-Kanpur Foundation."}]}', 'prompt_tokens': 309, 'completion_tokens': 314, 'total_tokens': 623, 'total_time': 0.948159365}

# %%
text_questions
# Out:
# {'questions': [{'question': "What is Abhay Bhushan Pandey's profession?",
#    'answer': 'Indian computer scientist.'},
#   {'question': 'What did Abhay Bhushan Pandey contribute to?',
#    'answer': 'development of the Internet TCP/IP architecture.'},
#   {'question': 'What protocols did Abhay Bhushan Pandey author?',
#    'answer': 'File Transfer Protocol and early versions of email protocols.'},
#   {'question': 'Where did Abhay Bhushan Pandey graduate from in 1965?',
#    'answer': 'Indian Institute of Technology Kanpur.'},
#   {'question': 'What degree did Abhay Bhushan Pandey receive from the MIT Sloan School of Management?',
#    'answer': 'Masters in electrical engineering and a degree in Management.'},
#   {'question': 'What networks did Abhay Bhushan Pandey work on developing FTP and email protocols for?',
#    'answer': 'ARPANet and subsequent Internet.'},
#   {'question': 'What positions did Abhay Bhushan Pandey hold at the Institute of Engineering and Rural Technology and Xerox?',
#    'answer': 'Director and senior manager in Engineering and Development.'},
#   {'question': 'What companies did Abhay Bhushan Pandey co-found?',
#    'answer': 'YieldUP International and Portola Communications.'},
#   {'question': 'What positions does Abhay Bhushan Pandey currently hold?',
#    'answer': 'chairman of Asquare Inc., Secretary of Indians for Collective Action and former President of the IIT-Kanpur Foundation.'}],
#  'generated_text': '{"questions":[{"question": "What is Abhay Bhushan Pandey\'s profession?", "answer": "Indian computer scientist."}, {"question": "What did Abhay Bhushan Pandey contribute to?", "answer": "development of the Internet TCP/IP architecture."}, {"question": "What protocols did Abhay Bhushan Pandey author?", "answer": "File Transfer Protocol and early versions of email protocols."}, {"question": "Where did Abhay Bhushan Pandey graduate from in 1965?", "answer": "Indian Institute of Technology Kanpur."}, {"question": "What degree did Abhay Bhushan Pandey receive from the MIT Sloan School of Management?", "answer": "Masters in electrical engineering and a degree in Management."}, {"question": "What networks did Abhay Bhushan Pandey work on developing FTP and email protocols for?", "answer": "ARPANet and subsequent Internet."}, {"question": "What positions did Abhay Bhushan Pandey hold at the Institute of Engineering and Rural Technology and Xerox?", "answer": "Director and senior manager in Engineering and Development."}, {"question": "What companies did Abhay Bhushan Pandey co-found?", "answer": "YieldUP International and Portola Communications."}, {"question": "What positions does Abhay Bhushan Pandey currently hold?", "answer": "chairman of Asquare Inc., Secretary of Indians for Collective Action and former President of the IIT-Kanpur Foundation."}]}',
#  'prompt_tokens': 309,
#  'completion_tokens': 314,
#  'total_tokens': 623,
#  'total_time': 0.948159365}

# %%
len(text_questions['questions'])
# Out:
# 9

# %% [markdown]
# ## Generate questions from each factual association extracted

# %%
questions_from_facts = []

for given_fact in facts['sentences']:

    fact_text = "{} {} {}".format(given_fact['subject'],
                                  given_fact['relation'],
                                  given_fact['object'])

    fact_questions = questions_generation_from_statement(groq_interface, fact_text)

    questions_from_facts.append({"statement": fact_text,
                                 "questions": fact_questions['questions']})
# Out:
# Generate questions from the simple factual statement. Do not create a generic question. Only output the JSON format, nothing else: {"questions":[{"question:": "<question-1>", "answer": "<answer-1>"}, ..., {"question": "<question-n>", "answer": "<answer-n>"}]}
#
# Statement: "Abhay Bhushan Pandey is an Indian computer scientist"
#
#
# ---------------------
# {"questions":[{"question": "Who is Abhay Bhushan Pandey?", "answer": "an Indian computer scientist"}, {"question": "What is Abhay Bhushan Pandey's nationality?", "answer": "Indian"}, {"question": "What is Abhay Bhushan Pandey's profession?", "answer": "computer scientist"}]}
# ---------------------
#
#
#
#
# ---------------------
# {"questions":[{"question": "Who is Abhay Bhushan Pandey?", "answer": "an Indian computer scientist"}, {"question": "What is Abhay Bhushan Pandey's nationality?", "answer": "Indian"}, {"question": "What is Abhay Bhushan Pandey's profession?", "answer": "computer scientist"}]}
# ---------------------
#
#
#
# {'questions': [{'question': 'Who is Abhay Bhushan Pandey?', 'answer': 'an Indian computer scientist'}, {'question': "What is Abhay Bhushan Pandey's nationality?", 'answer': 'Indian'}, {'question': "What is Abhay Bhushan Pandey's profession?", 'answer': 'computer scientist'}], 'generated_text': '{"questions":[{"question": "Who is Abhay Bhushan Pandey?", "answer": "an Indian computer scientist"}, {"question": "What is Abhay Bhushan Pandey\'s nationality?", "answer": "Indian"}, {"question": "What is Abhay Bhushan Pandey\'s profession?", "answer": "computer scientist"}]}', 'prompt_tokens': 88, 'completion_tokens': 72, 'total_tokens': 160, 'total_time': 0.227861762}
#
# Generate questions from the simple factual statement. Do not create a generic question. Only output the JSON format, nothing else: {"questions":[{"question:": "<question-1>", "answer": "<answer-1>"}, ..., {"question": "<question-n>", "answer": "<answer-n>"}]}
#
# Statement: "Abhay Bhushan Pandey made significant contributions to the development of the Internet TCP/IP architecture"
#
#
# ---------------------
# {"questions":[{"question": "Who made significant contributions to the development of the Internet TCP/IP architecture?", "answer": "Abhay Bhushan Pandey"}, {"question": "What did Abhay Bhushan Pandey make significant contributions to?", "answer": "the development of the Internet TCP/IP architecture"}]}
# ---------------------
#
#
#
#
# ---------------------
# {"questions":[{"question": "Who made significant contributions to the development of the Internet TCP/IP architecture?", "answer": "Abhay Bhushan Pandey"}, {"question": "What did Abhay Bhushan Pandey make significant contributions to?", "answer": "the development of the Internet TCP/IP architecture"}]}
# ---------------------
#
#
#
# {'questions': [{'question': 'Who made significant contributions to the development of the Internet TCP/IP architecture?', 'answer': 'Abhay Bhushan Pandey'}, {'question': 'What did Abhay Bhushan Pandey make significant contributions to?', 'answer': 'the development of the Internet TCP/IP architecture'}], 'generated_text': '{"questions":[{"question": "Who made significant contributions to the development of the Internet TCP/IP architecture?", "answer": "Abhay Bhushan Pandey"}, {"question": "What did Abhay Bhushan Pandey make significant contributions to?", "answer": "the development of the Internet TCP/IP architecture"}]}', 'prompt_tokens': 95, 'completion_tokens': 65, 'total_tokens': 160, 'total_time': 0.203851827}
#
# Generate questions from the simple factual statement. Do not create a generic question. Only output the JSON format, nothing else: {"questions":[{"question:": "<question-1>", "answer": "<answer-1>"}, ..., {"question": "<question-n>", "answer": "<answer-n>"}]}
#
# Statement: "Abhay Bhushan Pandey is the author of the File Transfer Protocol and early versions of email protocols"
#
#
# ---------------------
# {"questions":[{"question": "Who is the author of the File Transfer Protocol?", "answer": "Abhay Bhushan Pandey"}, {"question": "What is Abhay Bhushan Pandey known for authoring?", "answer": "the File Transfer Protocol and early versions of email protocols"}, {"question": "Who developed early versions of email protocols?", "answer": "Abhay Bhushan Pandey"}]}
# ---------------------
#
#
#
#
# ---------------------
# {"questions":[{"question": "Who is the author of the File Transfer Protocol?", "answer": "Abhay Bhushan Pandey"}, {"question": "What is Abhay Bhushan Pandey known for authoring?", "answer": "the File Transfer Protocol and early versions of email protocols"}, {"question": "Who developed early versions of email protocols?", "answer": "Abhay Bhushan Pandey"}]}
# ---------------------
#
#
#
# {'questions': [{'question': 'Who is the author of the File Transfer Protocol?', 'answer': 'Abhay Bhushan Pandey'}, {'question': 'What is Abhay Bhushan Pandey known for authoring?', 'answer': 'the File Transfer Protocol and early versions of email protocols'}, {'question': 'Who developed early versions of email protocols?', 'answer': 'Abhay Bhushan Pandey'}], 'generated_text': '{"questions":[{"question": "Who is the author of the File Transfer Protocol?", "answer": "Abhay Bhushan Pandey"}, {"question": "What is Abhay Bhushan Pandey known for authoring?", "answer": "the File Transfer Protocol and early versions of email protocols"}, {"question": "Who developed early versions of email protocols?", "answer": "Abhay Bhushan Pandey"}]}', 'prompt_tokens': 97, 'completion_tokens': 87, 'total_tokens': 184, 'total_time': 0.266418458}
#
# Generate questions from the simple factual statement. Do not create a generic question. Only output the JSON format, nothing else: {"questions":[{"question:": "<question-1>", "answer": "<answer-1>"}, ..., {"question": "<question-n>", "answer": "<answer-n>"}]}
#
# Statement: "Abhay Bhushan Pandey graduated from the Indian Institute of Technology Kanpur in 1965 with a B.Tech in electrical engineering"
#
#
# ---------------------
# {"questions":[{"question": "Where did Abhay Bhushan Pandey graduate from?", "answer": "Indian Institute of Technology Kanpur"}, {"question": "What year did Abhay Bhushan Pandey graduate?", "answer": "1965"}, {"question": "What degree did Abhay Bhushan Pandey earn?", "answer": "B.Tech"}, {"question": "What was Abhay Bhushan Pandey's field of study?", "answer": "electrical engineering"}]}
# ---------------------
#
#
#
#
# ---------------------
# {"questions":[{"question": "Where did Abhay Bhushan Pandey graduate from?", "answer": "Indian Institute of Technology Kanpur"}, {"question": "What year did Abhay Bhushan Pandey graduate?", "answer": "1965"}, {"question": "What degree did Abhay Bhushan Pandey earn?", "answer": "B.Tech"}, {"question": "What was Abhay Bhushan Pandey's field of study?", "answer": "electrical engineering"}]}
# ---------------------
#
#
#
# {'questions': [{'question': 'Where did Abhay Bhushan Pandey graduate from?', 'answer': 'Indian Institute of Technology Kanpur'}, {'question': 'What year did Abhay Bhushan Pandey graduate?', 'answer': '1965'}, {'question': 'What degree did Abhay Bhushan Pandey earn?', 'answer': 'B.Tech'}, {'question': "What was Abhay Bhushan Pandey's field of study?", 'answer': 'electrical engineering'}], 'generated_text': '{"questions":[{"question": "Where did Abhay Bhushan Pandey graduate from?", "answer": "Indian Institute of Technology Kanpur"}, {"question": "What year did Abhay Bhushan Pandey graduate?", "answer": "1965"}, {"question": "What degree did Abhay Bhushan Pandey earn?", "answer": "B.Tech"}, {"question": "What was Abhay Bhushan Pandey\'s field of study?", "answer": "electrical engineering"}]}', 'prompt_tokens': 104, 'completion_tokens': 104, 'total_tokens': 208, 'total_time': 0.316150473}
#
# Generate questions from the simple factual statement. Do not create a generic question. Only output the JSON format, nothing else: {"questions":[{"question:": "<question-1>", "answer": "<answer-1>"}, ..., {"question": "<question-n>", "answer": "<answer-n>"}]}
#
# Statement: "Abhay Bhushan Pandey received a Masters in electrical engineering and a degree in Management from the MIT Sloan School of Management"
#
#
# ---------------------
# {"questions":[{"question": "What degree did Abhay Bhushan Pandey receive in electrical engineering?", "answer": "Masters"}, {"question": "From which school did Abhay Bhushan Pandey receive a degree in Management?", "answer": "MIT Sloan School of Management"}]}
# ---------------------
#
#
#
#
# ---------------------
# {"questions":[{"question": "What degree did Abhay Bhushan Pandey receive in electrical engineering?", "answer": "Masters"}, {"question": "From which school did Abhay Bhushan Pandey receive a degree in Management?", "answer": "MIT Sloan School of Management"}]}
# ---------------------
#
#
#
# {'questions': [{'question': 'What degree did Abhay Bhushan Pandey receive in electrical engineering?', 'answer': 'Masters'}, {'question': 'From which school did Abhay Bhushan Pandey receive a degree in Management?', 'answer': 'MIT Sloan School of Management'}], 'generated_text': '{"questions":[{"question": "What degree did Abhay Bhushan Pandey receive in electrical engineering?", "answer": "Masters"}, {"question": "From which school did Abhay Bhushan Pandey receive a degree in Management?", "answer": "MIT Sloan School of Management"}]}', 'prompt_tokens': 101, 'completion_tokens': 61, 'total_tokens': 162, 'total_time': 0.192956711}
#
# Generate questions from the simple factual statement. Do not create a generic question. Only output the JSON format, nothing else: {"questions":[{"question:": "<question-1>", "answer": "<answer-1>"}, ..., {"question": "<question-n>", "answer": "<answer-n>"}]}
#
# Statement: "Abhay Bhushan Pandey worked on developing FTP and email protocols for ARPANet and subsequent Internet"
#
#
# ---------------------
# {"questions":[{"question": "Who worked on developing FTP and email protocols for ARPANet and subsequent Internet?", "answer": "Abhay Bhushan Pandey"}, {"question": "What protocols did Abhay Bhushan Pandey work on developing for ARPANet and subsequent Internet?", "answer": "FTP and email protocols"}, {"question": "What networks did Abhay Bhushan Pandey work on developing FTP and email protocols for?", "answer": "ARPANet and subsequent Internet"}]}
# ---------------------
#
#
#
#
# ---------------------
# {"questions":[{"question": "Who worked on developing FTP and email protocols for ARPANet and subsequent Internet?", "answer": "Abhay Bhushan Pandey"}, {"question": "What protocols did Abhay Bhushan Pandey work on developing for ARPANet and subsequent Internet?", "answer": "FTP and email protocols"}, {"question": "What networks did Abhay Bhushan Pandey work on developing FTP and email protocols for?", "answer": "ARPANet and subsequent Internet"}]}
# ---------------------
#
#
#
# {'questions': [{'question': 'Who worked on developing FTP and email protocols for ARPANet and subsequent Internet?', 'answer': 'Abhay Bhushan Pandey'}, {'question': 'What protocols did Abhay Bhushan Pandey work on developing for ARPANet and subsequent Internet?', 'answer': 'FTP and email protocols'}, {'question': 'What networks did Abhay Bhushan Pandey work on developing FTP and email protocols for?', 'answer': 'ARPANet and subsequent Internet'}], 'generated_text': '{"questions":[{"question": "Who worked on developing FTP and email protocols for ARPANet and subsequent Internet?", "answer": "Abhay Bhushan Pandey"}, {"question": "What protocols did Abhay Bhushan Pandey work on developing for ARPANet and subsequent Internet?", "answer": "FTP and email protocols"}, {"question": "What networks did Abhay Bhushan Pandey work on developing FTP and email protocols for?", "answer": "ARPANet and subsequent Internet"}]}', 'prompt_tokens': 97, 'completion_tokens': 104, 'total_tokens': 201, 'total_time': 0.314299926}
#
# Generate questions from the simple factual statement. Do not create a generic question. Only output the JSON format, nothing else: {"questions":[{"question:": "<question-1>", "answer": "<answer-1>"}, ..., {"question": "<question-n>", "answer": "<answer-n>"}]}
#
# Statement: "Abhay Bhushan Pandey was a Director at the Institute of Engineering and Rural Technology in Allahabad"
#
#
# ---------------------
# {"questions":[{"question": "Who was a Director at the Institute of Engineering and Rural Technology in Allahabad?", "answer": "Abhay Bhushan Pandey"}, {"question": "What was Abhay Bhushan Pandey's position at the Institute of Engineering and Rural Technology in Allahabad?", "answer": "Director"}, {"question": "At which institute was Abhay Bhushan Pandey a Director?", "answer": "Institute of Engineering and Rural Technology"}, {"question": "In which city was Abhay Bhushan Pandey a Director at the Institute of Engineering and Rural Technology?", "answer": "Allahabad"}]}
# ---------------------
#
#
#
#
# ---------------------
# {"questions":[{"question": "Who was a Director at the Institute of Engineering and Rural Technology in Allahabad?", "answer": "Abhay Bhushan Pandey"}, {"question": "What was Abhay Bhushan Pandey's position at the Institute of Engineering and Rural Technology in Allahabad?", "answer": "Director"}, {"question": "At which institute was Abhay Bhushan Pandey a Director?", "answer": "Institute of Engineering and Rural Technology"}, {"question": "In which city was Abhay Bhushan Pandey a Director at the Institute of Engineering and Rural Technology?", "answer": "Allahabad"}]}
# ---------------------
#
#
#
# {'questions': [{'question': 'Who was a Director at the Institute of Engineering and Rural Technology in Allahabad?', 'answer': 'Abhay Bhushan Pandey'}, {'question': "What was Abhay Bhushan Pandey's position at the Institute of Engineering and Rural Technology in Allahabad?", 'answer': 'Director'}, {'question': 'At which institute was Abhay Bhushan Pandey a Director?', 'answer': 'Institute of Engineering and Rural Technology'}, {'question': 'In which city was Abhay Bhushan Pandey a Director at the Institute of Engineering and Rural Technology?', 'answer': 'Allahabad'}], 'generated_text': '{"questions":[{"question": "Who was a Director at the Institute of Engineering and Rural Technology in Allahabad?", "answer": "Abhay Bhushan Pandey"}, {"question": "What was Abhay Bhushan Pandey\'s position at the Institute of Engineering and Rural Technology in Allahabad?", "answer": "Director"}, {"question": "At which institute was Abhay Bhushan Pandey a Director?", "answer": "Institute of Engineering and Rural Technology"}, {"question": "In which city was Abhay Bhushan Pandey a Director at the Institute of Engineering and Rural Technology?", "answer": "Allahabad"}]}', 'prompt_tokens': 97, 'completion_tokens': 133, 'total_tokens': 230, 'total_time': 0.398004162}
#
# Generate questions from the simple factual statement. Do not create a generic question. Only output the JSON format, nothing else: {"questions":[{"question:": "<question-1>", "answer": "<answer-1>"}, ..., {"question": "<question-n>", "answer": "<answer-n>"}]}
#
# Statement: "Abhay Bhushan Pandey was a senior manager in Engineering and Development of Xerox"
#
#
# ---------------------
# {"questions":[{"question": "Who was a senior manager in Engineering and Development of Xerox?", "answer": "Abhay Bhushan Pandey"}, {"question": "What was Abhay Bhushan Pandey's role in Xerox?", "answer": "senior manager in Engineering and Development"}]}
# ---------------------
#
#
#
#
# ---------------------
# {"questions":[{"question": "Who was a senior manager in Engineering and Development of Xerox?", "answer": "Abhay Bhushan Pandey"}, {"question": "What was Abhay Bhushan Pandey's role in Xerox?", "answer": "senior manager in Engineering and Development"}]}
# ---------------------
#
#
#
# {'questions': [{'question': 'Who was a senior manager in Engineering and Development of Xerox?', 'answer': 'Abhay Bhushan Pandey'}, {'question': "What was Abhay Bhushan Pandey's role in Xerox?", 'answer': 'senior manager in Engineering and Development'}], 'generated_text': '{"questions":[{"question": "Who was a senior manager in Engineering and Development of Xerox?", "answer": "Abhay Bhushan Pandey"}, {"question": "What was Abhay Bhushan Pandey\'s role in Xerox?", "answer": "senior manager in Engineering and Development"}]}', 'prompt_tokens': 94, 'completion_tokens': 64, 'total_tokens': 158, 'total_time': 0.200144919}
#
# Generate questions from the simple factual statement. Do not create a generic question. Only output the JSON format, nothing else: {"questions":[{"question:": "<question-1>", "answer": "<answer-1>"}, ..., {"question": "<question-n>", "answer": "<answer-n>"}]}
#
# Statement: "Abhay Bhushan Pandey was a co-founder of YieldUP International"
#
#
# ---------------------
# {"questions":[{"question": "Who was a co-founder of YieldUP International?", "answer": "Abhay Bhushan Pandey"}, {"question": "What was Abhay Bhushan Pandey a co-founder of?", "answer": "YieldUP International"}]}
# ---------------------
#
#
#
#
# ---------------------
# {"questions":[{"question": "Who was a co-founder of YieldUP International?", "answer": "Abhay Bhushan Pandey"}, {"question": "What was Abhay Bhushan Pandey a co-founder of?", "answer": "YieldUP International"}]}
# ---------------------
#
#
#
# {'questions': [{'question': 'Who was a co-founder of YieldUP International?', 'answer': 'Abhay Bhushan Pandey'}, {'question': 'What was Abhay Bhushan Pandey a co-founder of?', 'answer': 'YieldUP International'}], 'generated_text': '{"questions":[{"question": "Who was a co-founder of YieldUP International?", "answer": "Abhay Bhushan Pandey"}, {"question": "What was Abhay Bhushan Pandey a co-founder of?", "answer": "YieldUP International"}]}', 'prompt_tokens': 91, 'completion_tokens': 57, 'total_tokens': 148, 'total_time': 0.180122124}
#
# Generate questions from the simple factual statement. Do not create a generic question. Only output the JSON format, nothing else: {"questions":[{"question:": "<question-1>", "answer": "<answer-1>"}, ..., {"question": "<question-n>", "answer": "<answer-n>"}]}
#
# Statement: "Abhay Bhushan Pandey co-founded Portola Communications"
#
#
# ---------------------
# {"questions":[{"question": "Who co-founded Portola Communications?", "answer": "Abhay Bhushan Pandey"}, {"question": "What company did Abhay Bhushan Pandey co-found?", "answer": "Portola Communications"}]}
# ---------------------
#
#
#
#
# ---------------------
# {"questions":[{"question": "Who co-founded Portola Communications?", "answer": "Abhay Bhushan Pandey"}, {"question": "What company did Abhay Bhushan Pandey co-found?", "answer": "Portola Communications"}]}
# ---------------------
#
#
#
# {'questions': [{'question': 'Who co-founded Portola Communications?', 'answer': 'Abhay Bhushan Pandey'}, {'question': 'What company did Abhay Bhushan Pandey co-found?', 'answer': 'Portola Communications'}], 'generated_text': '{"questions":[{"question": "Who co-founded Portola Communications?", "answer": "Abhay Bhushan Pandey"}, {"question": "What company did Abhay Bhushan Pandey co-found?", "answer": "Portola Communications"}]}', 'prompt_tokens': 88, 'completion_tokens': 52, 'total_tokens': 140, 'total_time': 0.164137363}
#
# Generate questions from the simple factual statement. Do not create a generic question. Only output the JSON format, nothing else: {"questions":[{"question:": "<question-1>", "answer": "<answer-1>"}, ..., {"question": "<question-n>", "answer": "<answer-n>"}]}
#
# Statement: "Abhay Bhushan Pandey is currently chairman of Asquare Inc"
#
#
# ---------------------
# {"questions":[{"question": "Who is the current chairman of Asquare Inc?", "answer": "Abhay Bhushan Pandey"}, {"question": "What is the position held by Abhay Bhushan Pandey in Asquare Inc?", "answer": "Chairman"}]}
# ---------------------
#
#
#
#
# ---------------------
# {"questions":[{"question": "Who is the current chairman of Asquare Inc?", "answer": "Abhay Bhushan Pandey"}, {"question": "What is the position held by Abhay Bhushan Pandey in Asquare Inc?", "answer": "Chairman"}]}
# ---------------------
#
#
#
# {'questions': [{'question': 'Who is the current chairman of Asquare Inc?', 'answer': 'Abhay Bhushan Pandey'}, {'question': 'What is the position held by Abhay Bhushan Pandey in Asquare Inc?', 'answer': 'Chairman'}], 'generated_text': '{"questions":[{"question": "Who is the current chairman of Asquare Inc?", "answer": "Abhay Bhushan Pandey"}, {"question": "What is the position held by Abhay Bhushan Pandey in Asquare Inc?", "answer": "Chairman"}]}', 'prompt_tokens': 90, 'completion_tokens': 59, 'total_tokens': 149, 'total_time': 0.184935704}
#
# Generate questions from the simple factual statement. Do not create a generic question. Only output the JSON format, nothing else: {"questions":[{"question:": "<question-1>", "answer": "<answer-1>"}, ..., {"question": "<question-n>", "answer": "<answer-n>"}]}
#
# Statement: "Abhay Bhushan Pandey serves as Secretary of Indians for Collective Action"
#
#
# ---------------------
# {"questions":[{"question": "Who serves as Secretary of Indians for Collective Action?", "answer": "Abhay Bhushan Pandey"}, {"question": "What position does Abhay Bhushan Pandey hold in Indians for Collective Action?", "answer": "Secretary"}]}
# ---------------------
#
#
#
#
# ---------------------
# {"questions":[{"question": "Who serves as Secretary of Indians for Collective Action?", "answer": "Abhay Bhushan Pandey"}, {"question": "What position does Abhay Bhushan Pandey hold in Indians for Collective Action?", "answer": "Secretary"}]}
# ---------------------
#
#
#
# {'questions': [{'question': 'Who serves as Secretary of Indians for Collective Action?', 'answer': 'Abhay Bhushan Pandey'}, {'question': 'What position does Abhay Bhushan Pandey hold in Indians for Collective Action?', 'answer': 'Secretary'}], 'generated_text': '{"questions":[{"question": "Who serves as Secretary of Indians for Collective Action?", "answer": "Abhay Bhushan Pandey"}, {"question": "What position does Abhay Bhushan Pandey hold in Indians for Collective Action?", "answer": "Secretary"}]}', 'prompt_tokens': 91, 'completion_tokens': 57, 'total_tokens': 148, 'total_time': 0.17989486200000002}
#
# Generate questions from the simple factual statement. Do not create a generic question. Only output the JSON format, nothing else: {"questions":[{"question:": "<question-1>", "answer": "<answer-1>"}, ..., {"question": "<question-n>", "answer": "<answer-n>"}]}
#
# Statement: "Abhay Bhushan Pandey is a former President of the IIT-Kanpur Foundation"
#
#
# ---------------------
# {"questions":[{"question": "Who is the former President of the IIT-Kanpur Foundation?", "answer": "Abhay Bhushan Pandey"}, {"question": "What position did Abhay Bhushan Pandey hold in the IIT-Kanpur Foundation?", "answer": "former President"}]}
# ---------------------
#
#
#
#
# ---------------------
# {"questions":[{"question": "Who is the former President of the IIT-Kanpur Foundation?", "answer": "Abhay Bhushan Pandey"}, {"question": "What position did Abhay Bhushan Pandey hold in the IIT-Kanpur Foundation?", "answer": "former President"}]}
# ---------------------
#
#
#
# {'questions': [{'question': 'Who is the former President of the IIT-Kanpur Foundation?', 'answer': 'Abhay Bhushan Pandey'}, {'question': 'What position did Abhay Bhushan Pandey hold in the IIT-Kanpur Foundation?', 'answer': 'former President'}], 'generated_text': '{"questions":[{"question": "Who is the former President of the IIT-Kanpur Foundation?", "answer": "Abhay Bhushan Pandey"}, {"question": "What position did Abhay Bhushan Pandey hold in the IIT-Kanpur Foundation?", "answer": "former President"}]}', 'prompt_tokens': 95, 'completion_tokens': 65, 'total_tokens': 160, 'total_time': 0.202540118}

# %%
questions_from_facts
# Out:
# [{'statement': 'Abhay Bhushan Pandey is an Indian computer scientist',
#   'questions': [{'question': 'Who is Abhay Bhushan Pandey?',
#     'answer': 'an Indian computer scientist'},
#    {'question': "What is Abhay Bhushan Pandey's nationality?",
#     'answer': 'Indian'},
#    {'question': "What is Abhay Bhushan Pandey's profession?",
#     'answer': 'computer scientist'}]},
#  {'statement': 'Abhay Bhushan Pandey made significant contributions to the development of the Internet TCP/IP architecture',
#   'questions': [{'question': 'Who made significant contributions to the development of the Internet TCP/IP architecture?',
#     'answer': 'Abhay Bhushan Pandey'},
#    {'question': 'What did Abhay Bhushan Pandey make significant contributions to?',
#     'answer': 'the development of the Internet TCP/IP architecture'}]},
#  {'statement': 'Abhay Bhushan Pandey is the author of the File Transfer Protocol and early versions of email protocols',
#   'questions': [{'question': 'Who is the author of the File Transfer Protocol?',
#     'answer': 'Abhay Bhushan Pandey'},
#    {'question': 'What is Abhay Bhushan Pandey known for authoring?',
#     'answer': 'the File Transfer Protocol and early versions of email protocols'},
#    {'question': 'Who developed early versions of email protocols?',
#     'answer': 'Abhay Bhushan Pandey'}]},
#  {'statement': 'Abhay Bhushan Pandey graduated from the Indian Institute of Technology Kanpur in 1965 with a B.Tech in electrical engineering',
#   'questions': [{'question': 'Where did Abhay Bhushan Pandey graduate from?',
#     'answer': 'Indian Institute of Technology Kanpur'},
#    {'question': 'What year did Abhay Bhushan Pandey graduate?',
#     'answer': '1965'},
#    {'question': 'What degree did Abhay Bhushan Pandey earn?',
#     'answer': 'B.Tech'},
#    {'question': "What was Abhay Bhushan Pandey's field of study?",
#     'answer': 'electrical engineering'}]},
#  {'statement': 'Abhay Bhushan Pandey received a Masters in electrical engineering and a degree in Management from the MIT Sloan School of Management',
#   'questions': [{'question': 'What degree did Abhay Bhushan Pandey receive in electrical engineering?',
#     'answer': 'Masters'},
#    {'question': 'From which school did Abhay Bhushan Pandey receive a degree in Management?',
#     'answer': 'MIT Sloan School of Management'}]},
#  {'statement': 'Abhay Bhushan Pandey worked on developing FTP and email protocols for ARPANet and subsequent Internet',
#   'questions': [{'question': 'Who worked on developing FTP and email protocols for ARPANet and subsequent Internet?',
#     'answer': 'Abhay Bhushan Pandey'},
#    {'question': 'What protocols did Abhay Bhushan Pandey work on developing for ARPANet and subsequent Internet?',
#     'answer': 'FTP and email protocols'},
#    {'question': 'What networks did Abhay Bhushan Pandey work on developing FTP and email protocols for?',
#     'answer': 'ARPANet and subsequent Internet'}]},
#  {'statement': 'Abhay Bhushan Pandey was a Director at the Institute of Engineering and Rural Technology in Allahabad',
#   'questions': [{'question': 'Who was a Director at the Institute of Engineering and Rural Technology in Allahabad?',
#     'answer': 'Abhay Bhushan Pandey'},
#    {'question': "What was Abhay Bhushan Pandey's position at the Institute of Engineering and Rural Technology in Allahabad?",
#     'answer': 'Director'},
#    {'question': 'At which institute was Abhay Bhushan Pandey a Director?',
#     'answer': 'Institute of Engineering and Rural Technology'},
#    {'question': 'In which city was Abhay Bhushan Pandey a Director at the Institute of Engineering and Rural Technology?',
#     'answer': 'Allahabad'}]},
#  {'statement': 'Abhay Bhushan Pandey was a senior manager in Engineering and Development of Xerox',
#   'questions': [{'question': 'Who was a senior manager in Engineering and Development of Xerox?',
#     'answer': 'Abhay Bhushan Pandey'},
#    {'question': "What was Abhay Bhushan Pandey's role in Xerox?",
#     'answer': 'senior manager in Engineering and Development'}]},
#  {'statement': 'Abhay Bhushan Pandey was a co-founder of YieldUP International',
#   'questions': [{'question': 'Who was a co-founder of YieldUP International?',
#     'answer': 'Abhay Bhushan Pandey'},
#    {'question': 'What was Abhay Bhushan Pandey a co-founder of?',
#     'answer': 'YieldUP International'}]},
#  {'statement': 'Abhay Bhushan Pandey co-founded Portola Communications',
#   'questions': [{'question': 'Who co-founded Portola Communications?',
#     'answer': 'Abhay Bhushan Pandey'},
#    {'question': 'What company did Abhay Bhushan Pandey co-found?',
#     'answer': 'Portola Communications'}]},
#  {'statement': 'Abhay Bhushan Pandey is currently chairman of Asquare Inc',
#   'questions': [{'question': 'Who is the current chairman of Asquare Inc?',
#     'answer': 'Abhay Bhushan Pandey'},
#    {'question': 'What is the position held by Abhay Bhushan Pandey in Asquare Inc?',
#     'answer': 'Chairman'}]},
#  {'statement': 'Abhay Bhushan Pandey serves as Secretary of Indians for Collective Action',
#   'questions': [{'question': 'Who serves as Secretary of Indians for Collective Action?',
#     'answer': 'Abhay Bhushan Pandey'},
#    {'question': 'What position does Abhay Bhushan Pandey hold in Indians for Collective Action?',
#     'answer': 'Secretary'}]},
#  {'statement': 'Abhay Bhushan Pandey is a former President of the IIT-Kanpur Foundation',
#   'questions': [{'question': 'Who is the former President of the IIT-Kanpur Foundation?',
#     'answer': 'Abhay Bhushan Pandey'},
#    {'question': 'What position did Abhay Bhushan Pandey hold in the IIT-Kanpur Foundation?',
#     'answer': 'former President'}]}]

# %%
len(questions_from_facts)
# Out:
# 13

# %%
all_facts_questions = []

for questions in questions_from_facts:
    all_facts_questions += questions['questions']

# %%
len(all_facts_questions)
# Out:
# 33

# %% [markdown]
# ## Save everything

# %%
with open("../../data/extracted_3_step_factual_associations_20240625.pkl", "wb") as output_file:
    pickle.dump({"facts": facts["sentences"],
                 "fact_results": facts,
                 "questions": text_questions["questions"],
                 "questions_results": text_questions,
                 "questions_from_facts": questions_from_facts,
                 "questions_from_facts_results": fact_questions}, output_file, pickle.HIGHEST_PROTOCOL)
